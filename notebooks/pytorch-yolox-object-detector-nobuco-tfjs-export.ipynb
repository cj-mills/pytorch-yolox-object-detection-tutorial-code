# %% [markdown]
# ## Setting Up Your Python Environment

# %%
# %%capture
# # Install PyTorch with CUDA
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# # Install additional dependencies
# !pip install pandas nobuco tensorflowjs

# # Install utility packages
# !pip install cjm_yolox_pytorch

# Downgrade tensorflow-related packages for nobuco 
# %pip install "keras<3.0.0" "tensorflow<2.16" "tensorflow-decision-forests<1.10.0"

# %% [markdown]
# ## Importing the Required Dependencies

# %%
# Import Python Standard Library dependencies
import json
from pathlib import Path

# Import YOLOX package
from cjm_yolox_pytorch.model import build_model
from cjm_yolox_pytorch.inference import YOLOXInferenceWrapper

# Import the pandas package
import pandas as pd

# Import PyTorch dependencies
import torch

# Import Nobuco dependencies
from nobuco import pytorch_to_keras, ChannelOrder

# Import TensorFlow.js dependencies
from tensorflowjs import converters, quantization
# Out:
# 2024-09-26 11:55:13.644174: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-26 11:55:13.666974: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-26 11:55:13.666993: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-26 11:55:13.667618: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-26 11:55:13.671812: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-26 11:55:14.160766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:root:TensorFlow Decision Forests 1.8.1 is compatible with the following TensorFlow Versions: ['2.15.0']. However, TensorFlow 2.15.1 was detected. This can cause issues with the TF API and symbols in the custom C++ ops. See the TF and TF-DF compatibility table at https://github.com/tensorflow/decision-forests/blob/main/documentation/known_issues.md#compatibility-table.

# %% [markdown]
# ## Setting Up the Project

# %% [markdown]
# ### Set the Directory Paths

# %%
# The name for the project
project_name = f"pytorch-yolox-object-detector"

# The path for the project folder
project_dir = Path(f"./{project_name}/")

# Create the project directory if it does not already exist
project_dir.mkdir(parents=True, exist_ok=True)

# The path to the checkpoint folder
checkpoint_dir = Path(project_dir/f"2024-09-21_20-57-52")

pd.Series({
    "Project Directory:": project_dir,
    "Checkpoint Directory:": checkpoint_dir,
}).to_frame().style.hide(axis='columns')
# Out:
# <style type="text/css">
# </style>
# <table id="T_27391">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27391_level0_row0" class="row_heading level0 row0" >Project Directory:</th>
#       <td id="T_27391_row0_col0" class="data row0 col0" >pytorch-yolox-object-detector</td>
#     </tr>
#     <tr>
#       <th id="T_27391_level0_row1" class="row_heading level0 row1" >Checkpoint Directory:</th>
#       <td id="T_27391_row1_col0" class="data row1 col0" >pytorch-yolox-object-detector/2024-09-21_20-57-52</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Loading the Checkpoint Data

# %% [markdown]
# ### Load the Colormap

# %%
# The colormap path
colormap_path = list(checkpoint_dir.glob('*colormap.json'))[0]

# Load the JSON colormap data
with open(colormap_path, 'r') as file:
        colormap_json = json.load(file)

# Convert the JSON data to a dictionary        
colormap_dict = {item['label']: item['color'] for item in colormap_json['items']}

# Extract the class names from the colormap
class_names = list(colormap_dict.keys())

# Make a copy of the colormap in integer format
int_colors = [tuple(int(c*255) for c in color) for color in colormap_dict.values()]

# %% [markdown]
# ### Load the Normalization Statistics

# %%
# The normalization stats path
norm_stats_path = checkpoint_dir/'norm_stats.json'

# Read the normalization stats from the JSON file
with open(norm_stats_path, "r") as f:
    norm_stats_dict = json.load(f)

# Convert the dictionary to a tuple
norm_stats = (norm_stats_dict["mean"], norm_stats_dict["std_dev"])

# Print the mean and standard deviation
pd.DataFrame(norm_stats)
# Out:
#      0    1    2
# 0  0.5  0.5  0.5
# 1  1.0  1.0  1.0

# %% [markdown]
# ### Load the Model Checkpoint

# %%
# The model checkpoint path
checkpoint_path = list(checkpoint_dir.glob('*.pth'))[0]

# Load the model checkpoint onto the CPU
model_checkpoint = torch.load(checkpoint_path, map_location='cpu')
# Out:
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.10/site-packages/nobuco/trace/trace.py:366: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   outputs = orig_method(*args, **kwargs)

# %% [markdown]
# ### Load the Trained YOLOX Model

# %%
# Select the YOLOX model configuration
model_type = checkpoint_path.stem

# Create a YOLOX model with the number of output classes equal to the number of class names
model = build_model(model_type, len(class_names))

# Initialize the model with the checkpoint parameters and buffers
model.load_state_dict(model_checkpoint)
# Out:
# The file ./pretrained_checkpoints/yolox_tiny.pth already exists and overwrite is set to False.
# <All keys matched successfully>

# %% [markdown]
# ## Converting the Model to TensorFlow

# %% [markdown]
# ### Prepare the Model for Inference

# %%
# Convert the normalization stats to tensors
mean_tensor = torch.tensor(norm_stats[0]).view(1, 3, 1, 1)
std_tensor = torch.tensor(norm_stats[1]).view(1, 3, 1, 1)

# Set the model to evaluation mode
model.eval();

# Wrap the model with preprocessing and post-processing steps
wrapped_model = YOLOXInferenceWrapper(model, 
                                      mean_tensor, 
                                      std_tensor, 
                                      scale_inp=True, # Scale input values from the rang [0,255] to [0,1]
                                      channels_last=False, # Have the model expect input in channels-last format
                                      run_box_and_prob_calculation=False # Enable or disable post-processing steps
                                     )

# %% [markdown]
# ### Prepare the Input Tensor

# %%
# input_tensor = torch.randn(1, 224, 224, 3)
input_tensor = torch.randn(1, 3, 224, 224)

# %% [markdown]
# ### Convert the PyTorch Model to Keras

# %%
keras_model = pytorch_to_keras(
    wrapped_model, 
    args=[input_tensor],
    outputs_channel_order=ChannelOrder.PYTORCH, 
)
# Out:
# [Nobuco] Tracing (DONE): 365 ops [00:00]
# [Nobuco] Converting: |██▋                                                             | 12/285 ops [00:00]
# 2024-09-26 11:55:16.609330: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-26 11:55:16.614279: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# [Nobuco] Converting (DONE): |████████████████████████████████████████████████████████| 285/285 ops [00:02]
# Legend:
#     Green — conversion successful
#     Yellow — conversion imprecise
#     Red — conversion failed
#     Red — no converter found
#     Bold — conversion applied directly
#     * — subgraph reused
#     Tensor — this output is not dependent on any of subgraph's input tensors
#     Tensor — this input is a parameter / constant
#     Tensor — this tensor is useless
#
# YOLOXInferenceWrapper[cjm_yolox_pytorch.inference](float32_0<1,3,224,224>) -> float32_661<1,1029,24>
#  │  __truediv__[torch.Tensor](float32_0<1,3,224,224>, 255.0) -> float32_1<1,3,224,224>
#  │   └· div[TensorBase](float32_0<1,3,224,224>, 255.0) -> float32_1<1,3,224,224>
#  │  __sub__[torch.Tensor](float32_1<1,3,224,224>, float32_2<1,3,1,1>) -> float32_3<1,3,224,224>
#  │   └· sub[TensorBase](float32_1<1,3,224,224>, float32_2<1,3,1,1>) -> float32_3<1,3,224,224>
#  │  __truediv__[torch.Tensor](float32_3<1,3,224,224>, float32_4<1,3,1,1>) -> float32_5<1,3,224,224>
#  │   └· div[TensorBase](float32_3<1,3,224,224>, float32_4<1,3,1,1>) -> float32_5<1,3,224,224>
#  │  YOLOX[cjm_yolox_pytorch.model](float32_5<1,3,224,224>) -> ([float32_559<1,19,28,28>, float32_600<1,19,14,14>, float32_641<1,19,7,7>], [float32_562<1,4,28,28>, float32_603<1,4,14,14>, float32_644<1,4,7,7>], [float32_565<1,1,28,28>, float32_606<1,1,14,14>, float32_647<1,1,7,7>])
#  │   │  CSPDarknet[cjm_yolox_pytorch.model](float32_5<1,3,224,224>) -> (float32_148<1,96,28,28>, float32_229<1,192,14,14>, float32_298<1,384,7,7>)
#  │   │   │  Focus[cjm_yolox_pytorch.model](float32_5<1,3,224,224>) -> float32_18<1,24,112,112>
#  │   │   │   │  __getitem__[TensorBase](float32_5<1,3,224,224>, (..., ::2, ::2)) -> float32_6<1,3,112,112>
#  │   │   │   │  __getitem__[TensorBase](float32_5<1,3,224,224>, (..., ::2, 1::2)) -> float32_7<1,3,112,112>
#  │   │   │   │  __getitem__[TensorBase](float32_5<1,3,224,224>, (..., 1::2, ::2)) -> float32_8<1,3,112,112>
#  │   │   │   │  __getitem__[TensorBase](float32_5<1,3,224,224>, (..., 1::2, 1::2)) -> float32_9<1,3,112,112>
#  │   │   │   │  cat[torch]((float32_6<1,3,112,112>, float32_7<1,3,112,112>, float32_8<1,3,112,112>, float32_9<1,3,112,112>), dim=1) -> float32_10<1,12,112,112>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_10<1,12,112,112>) -> float32_18<1,24,112,112>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_10<1,12,112,112>) -> float32_12<1,24,112,112>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_10<1,12,112,112>, float32_11<24,12,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_12<1,24,112,112>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_12<1,24,112,112>) -> float32_17<1,24,112,112>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_12<1,24,112,112>, float32_13<24>, float32_14<24>, float32_15<24>, float32_16<24>, False, 0.03, 0.001) -> float32_17<1,24,112,112>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_12<1,24,112,112>, float32_15<24>, float32_16<24>, float32_13<24>, float32_14<24>, False, 0.03, 0.001, True) -> float32_17<1,24,112,112>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_17<1,24,112,112>) -> float32_18<1,24,112,112>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_17<1,24,112,112>, inplace=False) -> float32_18<1,24,112,112>
#  │   │   │  Sequential[torch.nn.modules.container](float32_18<1,24,112,112>) -> float32_67<1,48,56,56>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_18<1,24,112,112>) -> float32_26<1,48,56,56>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_18<1,24,112,112>) -> float32_20<1,48,56,56>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_18<1,24,112,112>, float32_19<48,24,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_20<1,48,56,56>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_20<1,48,56,56>) -> float32_25<1,48,56,56>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_20<1,48,56,56>, float32_21<48>, float32_22<48>, float32_23<48>, float32_24<48>, False, 0.03, 0.001) -> float32_25<1,48,56,56>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_20<1,48,56,56>, float32_23<48>, float32_24<48>, float32_21<48>, float32_22<48>, False, 0.03, 0.001, True) -> float32_25<1,48,56,56>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_25<1,48,56,56>) -> float32_26<1,48,56,56>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_25<1,48,56,56>, inplace=False) -> float32_26<1,48,56,56>
#  │   │   │   ├· CSPLayer[cjm_yolox_pytorch.model](float32_26<1,48,56,56>) -> float32_67<1,48,56,56>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_26<1,48,56,56>) -> float32_34<1,24,56,56>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_26<1,48,56,56>) -> float32_28<1,24,56,56>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_26<1,48,56,56>, float32_27<24,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_28<1,24,56,56>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_28<1,24,56,56>) -> float32_33<1,24,56,56>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_28<1,24,56,56>, float32_29<24>, float32_30<24>, float32_31<24>, float32_32<24>, False, 0.03, 0.001) -> float32_33<1,24,56,56>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_28<1,24,56,56>, float32_31<24>, float32_32<24>, float32_29<24>, float32_30<24>, False, 0.03, 0.001, True) -> float32_33<1,24,56,56>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_33<1,24,56,56>) -> float32_34<1,24,56,56>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_33<1,24,56,56>, inplace=False) -> float32_34<1,24,56,56>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_34<1,24,56,56>) -> float32_50<1,24,56,56>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_34<1,24,56,56>) -> float32_42<1,24,56,56>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_34<1,24,56,56>) -> float32_36<1,24,56,56>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_34<1,24,56,56>, float32_35<24,24,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_36<1,24,56,56>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_36<1,24,56,56>) -> float32_41<1,24,56,56>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_36<1,24,56,56>, float32_37<24>, float32_38<24>, float32_39<24>, float32_40<24>, False, 0.03, 0.001) -> float32_41<1,24,56,56>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_36<1,24,56,56>, float32_39<24>, float32_40<24>, float32_37<24>, float32_38<24>, False, 0.03, 0.001, True) -> float32_41<1,24,56,56>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_41<1,24,56,56>) -> float32_42<1,24,56,56>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_41<1,24,56,56>, inplace=False) -> float32_42<1,24,56,56>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_42<1,24,56,56>) -> float32_50<1,24,56,56>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_42<1,24,56,56>) -> float32_44<1,24,56,56>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_42<1,24,56,56>, float32_43<24,24,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_44<1,24,56,56>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_44<1,24,56,56>) -> float32_49<1,24,56,56>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_44<1,24,56,56>, float32_45<24>, float32_46<24>, float32_47<24>, float32_48<24>, False, 0.03, 0.001) -> float32_49<1,24,56,56>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_44<1,24,56,56>, float32_47<24>, float32_48<24>, float32_45<24>, float32_46<24>, False, 0.03, 0.001, True) -> float32_49<1,24,56,56>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_49<1,24,56,56>) -> float32_50<1,24,56,56>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_49<1,24,56,56>, inplace=False) -> float32_50<1,24,56,56>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_34<1,24,56,56>) -> float32_34<1,24,56,56>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   ├· __iadd__[torch.Tensor](float32_50<1,24,56,56>, float32_34<1,24,56,56>) -> float32_50<1,24,56,56>
#  │   │   │   │   │   └   └· add_[TensorBase](float32_50<1,24,56,56>, float32_34<1,24,56,56>) -> float32_50<1,24,56,56>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_26<1,48,56,56>) -> float32_58<1,24,56,56>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_26<1,48,56,56>) -> float32_52<1,24,56,56>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_26<1,48,56,56>, float32_51<24,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_52<1,24,56,56>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_52<1,24,56,56>) -> float32_57<1,24,56,56>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_52<1,24,56,56>, float32_53<24>, float32_54<24>, float32_55<24>, float32_56<24>, False, 0.03, 0.001) -> float32_57<1,24,56,56>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_52<1,24,56,56>, float32_55<24>, float32_56<24>, float32_53<24>, float32_54<24>, False, 0.03, 0.001, True) -> float32_57<1,24,56,56>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_57<1,24,56,56>) -> float32_58<1,24,56,56>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_57<1,24,56,56>, inplace=False) -> float32_58<1,24,56,56>
#  │   │   │   │   │  cat[torch]((float32_50<1,24,56,56>, float32_58<1,24,56,56>), dim=1) -> float32_59<1,48,56,56>
#  │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_59<1,48,56,56>) -> float32_67<1,48,56,56>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_59<1,48,56,56>) -> float32_61<1,48,56,56>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_59<1,48,56,56>, float32_60<48,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_61<1,48,56,56>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_61<1,48,56,56>) -> float32_66<1,48,56,56>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_61<1,48,56,56>, float32_62<48>, float32_63<48>, float32_64<48>, float32_65<48>, False, 0.03, 0.001) -> float32_66<1,48,56,56>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_61<1,48,56,56>, float32_64<48>, float32_65<48>, float32_62<48>, float32_63<48>, False, 0.03, 0.001, True) -> float32_66<1,48,56,56>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_66<1,48,56,56>) -> float32_67<1,48,56,56>
#  │   │   │   └   └   └   └· silu[torch.nn.functional](float32_66<1,48,56,56>, inplace=False) -> float32_67<1,48,56,56>
#  │   │   ├· Sequential[torch.nn.modules.container](float32_67<1,48,56,56>) -> float32_148<1,96,28,28>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_67<1,48,56,56>) -> float32_75<1,96,28,28>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_67<1,48,56,56>) -> float32_69<1,96,28,28>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_67<1,48,56,56>, float32_68<96,48,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_69<1,96,28,28>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_69<1,96,28,28>) -> float32_74<1,96,28,28>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_69<1,96,28,28>, float32_70<96>, float32_71<96>, float32_72<96>, float32_73<96>, False, 0.03, 0.001) -> float32_74<1,96,28,28>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_69<1,96,28,28>, float32_72<96>, float32_73<96>, float32_70<96>, float32_71<96>, False, 0.03, 0.001, True) -> float32_74<1,96,28,28>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_74<1,96,28,28>) -> float32_75<1,96,28,28>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_74<1,96,28,28>, inplace=False) -> float32_75<1,96,28,28>
#  │   │   │   ├· CSPLayer[cjm_yolox_pytorch.model](float32_75<1,96,28,28>) -> float32_148<1,96,28,28>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_75<1,96,28,28>) -> float32_83<1,48,28,28>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_75<1,96,28,28>) -> float32_77<1,48,28,28>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_75<1,96,28,28>, float32_76<48,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_77<1,48,28,28>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_77<1,48,28,28>) -> float32_82<1,48,28,28>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_77<1,48,28,28>, float32_78<48>, float32_79<48>, float32_80<48>, float32_81<48>, False, 0.03, 0.001) -> float32_82<1,48,28,28>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_77<1,48,28,28>, float32_80<48>, float32_81<48>, float32_78<48>, float32_79<48>, False, 0.03, 0.001, True) -> float32_82<1,48,28,28>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_82<1,48,28,28>) -> float32_83<1,48,28,28>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_82<1,48,28,28>, inplace=False) -> float32_83<1,48,28,28>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_83<1,48,28,28>) -> float32_99<1,48,28,28>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_83<1,48,28,28>) -> float32_91<1,48,28,28>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_83<1,48,28,28>) -> float32_85<1,48,28,28>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_83<1,48,28,28>, float32_84<48,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_85<1,48,28,28>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_85<1,48,28,28>) -> float32_90<1,48,28,28>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_85<1,48,28,28>, float32_86<48>, float32_87<48>, float32_88<48>, float32_89<48>, False, 0.03, 0.001) -> float32_90<1,48,28,28>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_85<1,48,28,28>, float32_88<48>, float32_89<48>, float32_86<48>, float32_87<48>, False, 0.03, 0.001, True) -> float32_90<1,48,28,28>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_90<1,48,28,28>) -> float32_91<1,48,28,28>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_90<1,48,28,28>, inplace=False) -> float32_91<1,48,28,28>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_91<1,48,28,28>) -> float32_99<1,48,28,28>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_91<1,48,28,28>) -> float32_93<1,48,28,28>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_91<1,48,28,28>, float32_92<48,48,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_93<1,48,28,28>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_93<1,48,28,28>) -> float32_98<1,48,28,28>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_93<1,48,28,28>, float32_94<48>, float32_95<48>, float32_96<48>, float32_97<48>, False, 0.03, 0.001) -> float32_98<1,48,28,28>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_93<1,48,28,28>, float32_96<48>, float32_97<48>, float32_94<48>, float32_95<48>, False, 0.03, 0.001, True) -> float32_98<1,48,28,28>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_98<1,48,28,28>) -> float32_99<1,48,28,28>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_98<1,48,28,28>, inplace=False) -> float32_99<1,48,28,28>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_83<1,48,28,28>) -> float32_83<1,48,28,28>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   ├· __iadd__[torch.Tensor](float32_99<1,48,28,28>, float32_83<1,48,28,28>) -> float32_99<1,48,28,28>
#  │   │   │   │   │   └   └· add_[TensorBase](float32_99<1,48,28,28>, float32_83<1,48,28,28>) -> float32_99<1,48,28,28>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_99<1,48,28,28>) -> float32_115<1,48,28,28>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_99<1,48,28,28>) -> float32_107<1,48,28,28>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_99<1,48,28,28>) -> float32_101<1,48,28,28>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_99<1,48,28,28>, float32_100<48,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_101<1,48,28,28>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_101<1,48,28,28>) -> float32_106<1,48,28,28>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_101<1,48,28,28>, float32_102<48>, float32_103<48>, float32_104<48>, float32_105<48>, False, 0.03, 0.001) -> float32_106<1,48,28,28>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_101<1,48,28,28>, float32_104<48>, float32_105<48>, float32_102<48>, float32_103<48>, False, 0.03, 0.001, True) -> float32_106<1,48,28,28>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_106<1,48,28,28>) -> float32_107<1,48,28,28>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_106<1,48,28,28>, inplace=False) -> float32_107<1,48,28,28>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_107<1,48,28,28>) -> float32_115<1,48,28,28>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_107<1,48,28,28>) -> float32_109<1,48,28,28>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_107<1,48,28,28>, float32_108<48,48,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_109<1,48,28,28>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_109<1,48,28,28>) -> float32_114<1,48,28,28>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_109<1,48,28,28>, float32_110<48>, float32_111<48>, float32_112<48>, float32_113<48>, False, 0.03, 0.001) -> float32_114<1,48,28,28>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_109<1,48,28,28>, float32_112<48>, float32_113<48>, float32_110<48>, float32_111<48>, False, 0.03, 0.001, True) -> float32_114<1,48,28,28>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_114<1,48,28,28>) -> float32_115<1,48,28,28>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_114<1,48,28,28>, inplace=False) -> float32_115<1,48,28,28>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_99<1,48,28,28>) -> float32_99<1,48,28,28>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   ├· __iadd__[torch.Tensor](float32_115<1,48,28,28>, float32_99<1,48,28,28>) -> float32_115<1,48,28,28>
#  │   │   │   │   │   └   └· add_[TensorBase](float32_115<1,48,28,28>, float32_99<1,48,28,28>) -> float32_115<1,48,28,28>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_115<1,48,28,28>) -> float32_131<1,48,28,28>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_115<1,48,28,28>) -> float32_123<1,48,28,28>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_115<1,48,28,28>) -> float32_117<1,48,28,28>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_115<1,48,28,28>, float32_116<48,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_117<1,48,28,28>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_117<1,48,28,28>) -> float32_122<1,48,28,28>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_117<1,48,28,28>, float32_118<48>, float32_119<48>, float32_120<48>, float32_121<48>, False, 0.03, 0.001) -> float32_122<1,48,28,28>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_117<1,48,28,28>, float32_120<48>, float32_121<48>, float32_118<48>, float32_119<48>, False, 0.03, 0.001, True) -> float32_122<1,48,28,28>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_122<1,48,28,28>) -> float32_123<1,48,28,28>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_122<1,48,28,28>, inplace=False) -> float32_123<1,48,28,28>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_123<1,48,28,28>) -> float32_131<1,48,28,28>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_123<1,48,28,28>) -> float32_125<1,48,28,28>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_123<1,48,28,28>, float32_124<48,48,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_125<1,48,28,28>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_125<1,48,28,28>) -> float32_130<1,48,28,28>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_125<1,48,28,28>, float32_126<48>, float32_127<48>, float32_128<48>, float32_129<48>, False, 0.03, 0.001) -> float32_130<1,48,28,28>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_125<1,48,28,28>, float32_128<48>, float32_129<48>, float32_126<48>, float32_127<48>, False, 0.03, 0.001, True) -> float32_130<1,48,28,28>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_130<1,48,28,28>) -> float32_131<1,48,28,28>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_130<1,48,28,28>, inplace=False) -> float32_131<1,48,28,28>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_115<1,48,28,28>) -> float32_115<1,48,28,28>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   ├· __iadd__[torch.Tensor](float32_131<1,48,28,28>, float32_115<1,48,28,28>) -> float32_131<1,48,28,28>
#  │   │   │   │   │   └   └· add_[TensorBase](float32_131<1,48,28,28>, float32_115<1,48,28,28>) -> float32_131<1,48,28,28>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_75<1,96,28,28>) -> float32_139<1,48,28,28>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_75<1,96,28,28>) -> float32_133<1,48,28,28>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_75<1,96,28,28>, float32_132<48,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_133<1,48,28,28>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_133<1,48,28,28>) -> float32_138<1,48,28,28>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_133<1,48,28,28>, float32_134<48>, float32_135<48>, float32_136<48>, float32_137<48>, False, 0.03, 0.001) -> float32_138<1,48,28,28>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_133<1,48,28,28>, float32_136<48>, float32_137<48>, float32_134<48>, float32_135<48>, False, 0.03, 0.001, True) -> float32_138<1,48,28,28>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_138<1,48,28,28>) -> float32_139<1,48,28,28>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_138<1,48,28,28>, inplace=False) -> float32_139<1,48,28,28>
#  │   │   │   │   │  cat[torch]((float32_131<1,48,28,28>, float32_139<1,48,28,28>), dim=1) -> float32_140<1,96,28,28>
#  │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_140<1,96,28,28>) -> float32_148<1,96,28,28>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_140<1,96,28,28>) -> float32_142<1,96,28,28>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_140<1,96,28,28>, float32_141<96,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_142<1,96,28,28>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_142<1,96,28,28>) -> float32_147<1,96,28,28>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_142<1,96,28,28>, float32_143<96>, float32_144<96>, float32_145<96>, float32_146<96>, False, 0.03, 0.001) -> float32_147<1,96,28,28>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_142<1,96,28,28>, float32_145<96>, float32_146<96>, float32_143<96>, float32_144<96>, False, 0.03, 0.001, True) -> float32_147<1,96,28,28>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_147<1,96,28,28>) -> float32_148<1,96,28,28>
#  │   │   │   └   └   └   └· silu[torch.nn.functional](float32_147<1,96,28,28>, inplace=False) -> float32_148<1,96,28,28>
#  │   │   ├· Sequential[torch.nn.modules.container](float32_148<1,96,28,28>) -> float32_229<1,192,14,14>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_148<1,96,28,28>) -> float32_156<1,192,14,14>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_148<1,96,28,28>) -> float32_150<1,192,14,14>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_148<1,96,28,28>, float32_149<192,96,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_150<1,192,14,14>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_150<1,192,14,14>) -> float32_155<1,192,14,14>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_150<1,192,14,14>, float32_151<192>, float32_152<192>, float32_153<192>, float32_154<192>, False, 0.03, 0.001) -> float32_155<1,192,14,14>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_150<1,192,14,14>, float32_153<192>, float32_154<192>, float32_151<192>, float32_152<192>, False, 0.03, 0.001, True) -> float32_155<1,192,14,14>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_155<1,192,14,14>) -> float32_156<1,192,14,14>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_155<1,192,14,14>, inplace=False) -> float32_156<1,192,14,14>
#  │   │   │   ├· CSPLayer[cjm_yolox_pytorch.model](float32_156<1,192,14,14>) -> float32_229<1,192,14,14>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_156<1,192,14,14>) -> float32_164<1,96,14,14>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_156<1,192,14,14>) -> float32_158<1,96,14,14>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_156<1,192,14,14>, float32_157<96,192,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_158<1,96,14,14>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_158<1,96,14,14>) -> float32_163<1,96,14,14>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_158<1,96,14,14>, float32_159<96>, float32_160<96>, float32_161<96>, float32_162<96>, False, 0.03, 0.001) -> float32_163<1,96,14,14>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_158<1,96,14,14>, float32_161<96>, float32_162<96>, float32_159<96>, float32_160<96>, False, 0.03, 0.001, True) -> float32_163<1,96,14,14>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_163<1,96,14,14>) -> float32_164<1,96,14,14>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_163<1,96,14,14>, inplace=False) -> float32_164<1,96,14,14>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_164<1,96,14,14>) -> float32_180<1,96,14,14>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_164<1,96,14,14>) -> float32_172<1,96,14,14>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_164<1,96,14,14>) -> float32_166<1,96,14,14>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_164<1,96,14,14>, float32_165<96,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_166<1,96,14,14>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_166<1,96,14,14>) -> float32_171<1,96,14,14>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_166<1,96,14,14>, float32_167<96>, float32_168<96>, float32_169<96>, float32_170<96>, False, 0.03, 0.001) -> float32_171<1,96,14,14>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_166<1,96,14,14>, float32_169<96>, float32_170<96>, float32_167<96>, float32_168<96>, False, 0.03, 0.001, True) -> float32_171<1,96,14,14>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_171<1,96,14,14>) -> float32_172<1,96,14,14>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_171<1,96,14,14>, inplace=False) -> float32_172<1,96,14,14>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_172<1,96,14,14>) -> float32_180<1,96,14,14>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_172<1,96,14,14>) -> float32_174<1,96,14,14>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_172<1,96,14,14>, float32_173<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_174<1,96,14,14>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_174<1,96,14,14>) -> float32_179<1,96,14,14>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_174<1,96,14,14>, float32_175<96>, float32_176<96>, float32_177<96>, float32_178<96>, False, 0.03, 0.001) -> float32_179<1,96,14,14>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_174<1,96,14,14>, float32_177<96>, float32_178<96>, float32_175<96>, float32_176<96>, False, 0.03, 0.001, True) -> float32_179<1,96,14,14>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_179<1,96,14,14>) -> float32_180<1,96,14,14>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_179<1,96,14,14>, inplace=False) -> float32_180<1,96,14,14>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_164<1,96,14,14>) -> float32_164<1,96,14,14>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   ├· __iadd__[torch.Tensor](float32_180<1,96,14,14>, float32_164<1,96,14,14>) -> float32_180<1,96,14,14>
#  │   │   │   │   │   └   └· add_[TensorBase](float32_180<1,96,14,14>, float32_164<1,96,14,14>) -> float32_180<1,96,14,14>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_180<1,96,14,14>) -> float32_196<1,96,14,14>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_180<1,96,14,14>) -> float32_188<1,96,14,14>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_180<1,96,14,14>) -> float32_182<1,96,14,14>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_180<1,96,14,14>, float32_181<96,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_182<1,96,14,14>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_182<1,96,14,14>) -> float32_187<1,96,14,14>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_182<1,96,14,14>, float32_183<96>, float32_184<96>, float32_185<96>, float32_186<96>, False, 0.03, 0.001) -> float32_187<1,96,14,14>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_182<1,96,14,14>, float32_185<96>, float32_186<96>, float32_183<96>, float32_184<96>, False, 0.03, 0.001, True) -> float32_187<1,96,14,14>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_187<1,96,14,14>) -> float32_188<1,96,14,14>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_187<1,96,14,14>, inplace=False) -> float32_188<1,96,14,14>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_188<1,96,14,14>) -> float32_196<1,96,14,14>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_188<1,96,14,14>) -> float32_190<1,96,14,14>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_188<1,96,14,14>, float32_189<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_190<1,96,14,14>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_190<1,96,14,14>) -> float32_195<1,96,14,14>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_190<1,96,14,14>, float32_191<96>, float32_192<96>, float32_193<96>, float32_194<96>, False, 0.03, 0.001) -> float32_195<1,96,14,14>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_190<1,96,14,14>, float32_193<96>, float32_194<96>, float32_191<96>, float32_192<96>, False, 0.03, 0.001, True) -> float32_195<1,96,14,14>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_195<1,96,14,14>) -> float32_196<1,96,14,14>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_195<1,96,14,14>, inplace=False) -> float32_196<1,96,14,14>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_180<1,96,14,14>) -> float32_180<1,96,14,14>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   ├· __iadd__[torch.Tensor](float32_196<1,96,14,14>, float32_180<1,96,14,14>) -> float32_196<1,96,14,14>
#  │   │   │   │   │   └   └· add_[TensorBase](float32_196<1,96,14,14>, float32_180<1,96,14,14>) -> float32_196<1,96,14,14>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_196<1,96,14,14>) -> float32_212<1,96,14,14>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_196<1,96,14,14>) -> float32_204<1,96,14,14>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_196<1,96,14,14>) -> float32_198<1,96,14,14>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_196<1,96,14,14>, float32_197<96,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_198<1,96,14,14>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_198<1,96,14,14>) -> float32_203<1,96,14,14>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_198<1,96,14,14>, float32_199<96>, float32_200<96>, float32_201<96>, float32_202<96>, False, 0.03, 0.001) -> float32_203<1,96,14,14>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_198<1,96,14,14>, float32_201<96>, float32_202<96>, float32_199<96>, float32_200<96>, False, 0.03, 0.001, True) -> float32_203<1,96,14,14>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_203<1,96,14,14>) -> float32_204<1,96,14,14>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_203<1,96,14,14>, inplace=False) -> float32_204<1,96,14,14>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_204<1,96,14,14>) -> float32_212<1,96,14,14>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_204<1,96,14,14>) -> float32_206<1,96,14,14>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_204<1,96,14,14>, float32_205<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_206<1,96,14,14>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_206<1,96,14,14>) -> float32_211<1,96,14,14>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_206<1,96,14,14>, float32_207<96>, float32_208<96>, float32_209<96>, float32_210<96>, False, 0.03, 0.001) -> float32_211<1,96,14,14>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_206<1,96,14,14>, float32_209<96>, float32_210<96>, float32_207<96>, float32_208<96>, False, 0.03, 0.001, True) -> float32_211<1,96,14,14>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_211<1,96,14,14>) -> float32_212<1,96,14,14>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_211<1,96,14,14>, inplace=False) -> float32_212<1,96,14,14>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_196<1,96,14,14>) -> float32_196<1,96,14,14>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   ├· __iadd__[torch.Tensor](float32_212<1,96,14,14>, float32_196<1,96,14,14>) -> float32_212<1,96,14,14>
#  │   │   │   │   │   └   └· add_[TensorBase](float32_212<1,96,14,14>, float32_196<1,96,14,14>) -> float32_212<1,96,14,14>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_156<1,192,14,14>) -> float32_220<1,96,14,14>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_156<1,192,14,14>) -> float32_214<1,96,14,14>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_156<1,192,14,14>, float32_213<96,192,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_214<1,96,14,14>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_214<1,96,14,14>) -> float32_219<1,96,14,14>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_214<1,96,14,14>, float32_215<96>, float32_216<96>, float32_217<96>, float32_218<96>, False, 0.03, 0.001) -> float32_219<1,96,14,14>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_214<1,96,14,14>, float32_217<96>, float32_218<96>, float32_215<96>, float32_216<96>, False, 0.03, 0.001, True) -> float32_219<1,96,14,14>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_219<1,96,14,14>) -> float32_220<1,96,14,14>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_219<1,96,14,14>, inplace=False) -> float32_220<1,96,14,14>
#  │   │   │   │   │  cat[torch]((float32_212<1,96,14,14>, float32_220<1,96,14,14>), dim=1) -> float32_221<1,192,14,14>
#  │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_221<1,192,14,14>) -> float32_229<1,192,14,14>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_221<1,192,14,14>) -> float32_223<1,192,14,14>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_221<1,192,14,14>, float32_222<192,192,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_223<1,192,14,14>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_223<1,192,14,14>) -> float32_228<1,192,14,14>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_223<1,192,14,14>, float32_224<192>, float32_225<192>, float32_226<192>, float32_227<192>, False, 0.03, 0.001) -> float32_228<1,192,14,14>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_223<1,192,14,14>, float32_226<192>, float32_227<192>, float32_224<192>, float32_225<192>, False, 0.03, 0.001, True) -> float32_228<1,192,14,14>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_228<1,192,14,14>) -> float32_229<1,192,14,14>
#  │   │   │   └   └   └   └· silu[torch.nn.functional](float32_228<1,192,14,14>, inplace=False) -> float32_229<1,192,14,14>
#  │   │   ├· Sequential[torch.nn.modules.container](float32_229<1,192,14,14>) -> float32_298<1,384,7,7>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_229<1,192,14,14>) -> float32_237<1,384,7,7>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_229<1,192,14,14>) -> float32_231<1,384,7,7>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_229<1,192,14,14>, float32_230<384,192,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_231<1,384,7,7>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_231<1,384,7,7>) -> float32_236<1,384,7,7>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_231<1,384,7,7>, float32_232<384>, float32_233<384>, float32_234<384>, float32_235<384>, False, 0.03, 0.001) -> float32_236<1,384,7,7>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_231<1,384,7,7>, float32_234<384>, float32_235<384>, float32_232<384>, float32_233<384>, False, 0.03, 0.001, True) -> float32_236<1,384,7,7>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_236<1,384,7,7>) -> float32_237<1,384,7,7>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_236<1,384,7,7>, inplace=False) -> float32_237<1,384,7,7>
#  │   │   │   │  SPPBottleneck[cjm_yolox_pytorch.model](float32_237<1,384,7,7>) -> float32_257<1,384,7,7>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_237<1,384,7,7>) -> float32_245<1,192,7,7>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_237<1,384,7,7>) -> float32_239<1,192,7,7>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_237<1,384,7,7>, float32_238<192,384,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_239<1,192,7,7>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_239<1,192,7,7>) -> float32_244<1,192,7,7>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_239<1,192,7,7>, float32_240<192>, float32_241<192>, float32_242<192>, float32_243<192>, False, 0.03, 0.001) -> float32_244<1,192,7,7>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_239<1,192,7,7>, float32_242<192>, float32_243<192>, float32_240<192>, float32_241<192>, False, 0.03, 0.001, True) -> float32_244<1,192,7,7>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_244<1,192,7,7>) -> float32_245<1,192,7,7>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_244<1,192,7,7>, inplace=False) -> float32_245<1,192,7,7>
#  │   │   │   │   │  MaxPool2d[torch.nn.modules.pooling](float32_245<1,192,7,7>) -> float32_246<1,192,7,7>
#  │   │   │   │   │   ├· max_pool2d[torch.nn.functional](float32_245<1,192,7,7>, 5, 1, 2, 1, ceil_mode=False, return_indices=False) -> float32_246<1,192,7,7>
#  │   │   │   │   │   └   └· max_pool2d[torch](float32_245<1,192,7,7>, 5, 1, 2, 1, False) -> float32_246<1,192,7,7>
#  │   │   │   │   │  MaxPool2d[torch.nn.modules.pooling](float32_245<1,192,7,7>) -> float32_247<1,192,7,7>
#  │   │   │   │   │   ├· max_pool2d[torch.nn.functional](float32_245<1,192,7,7>, 9, 1, 4, 1, ceil_mode=False, return_indices=False) -> float32_247<1,192,7,7>
#  │   │   │   │   │   └   └· max_pool2d[torch](float32_245<1,192,7,7>, 9, 1, 4, 1, False) -> float32_247<1,192,7,7>
#  │   │   │   │   │  MaxPool2d[torch.nn.modules.pooling](float32_245<1,192,7,7>) -> float32_248<1,192,7,7>
#  │   │   │   │   │   ├· max_pool2d[torch.nn.functional](float32_245<1,192,7,7>, 13, 1, 6, 1, ceil_mode=False, return_indices=False) -> float32_248<1,192,7,7>
#  │   │   │   │   │   └   └· max_pool2d[torch](float32_245<1,192,7,7>, 13, 1, 6, 1, False) -> float32_248<1,192,7,7>
#  │   │   │   │   │  cat[torch]([float32_245<1,192,7,7>, float32_246<1,192,7,7>, float32_247<1,192,7,7>, float32_248<1,192,7,7>], dim=1) -> float32_249<1,768,7,7>
#  │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_249<1,768,7,7>) -> float32_257<1,384,7,7>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_249<1,768,7,7>) -> float32_251<1,384,7,7>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_249<1,768,7,7>, float32_250<384,768,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_251<1,384,7,7>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_251<1,384,7,7>) -> float32_256<1,384,7,7>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_251<1,384,7,7>, float32_252<384>, float32_253<384>, float32_254<384>, float32_255<384>, False, 0.03, 0.001) -> float32_256<1,384,7,7>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_251<1,384,7,7>, float32_254<384>, float32_255<384>, float32_252<384>, float32_253<384>, False, 0.03, 0.001, True) -> float32_256<1,384,7,7>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_256<1,384,7,7>) -> float32_257<1,384,7,7>
#  │   │   │   │   └   └   └· silu[torch.nn.functional](float32_256<1,384,7,7>, inplace=False) -> float32_257<1,384,7,7>
#  │   │   │   ├· CSPLayer[cjm_yolox_pytorch.model](float32_257<1,384,7,7>) -> float32_298<1,384,7,7>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_257<1,384,7,7>) -> float32_265<1,192,7,7>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_257<1,384,7,7>) -> float32_259<1,192,7,7>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_257<1,384,7,7>, float32_258<192,384,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_259<1,192,7,7>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_259<1,192,7,7>) -> float32_264<1,192,7,7>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_259<1,192,7,7>, float32_260<192>, float32_261<192>, float32_262<192>, float32_263<192>, False, 0.03, 0.001) -> float32_264<1,192,7,7>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_259<1,192,7,7>, float32_262<192>, float32_263<192>, float32_260<192>, float32_261<192>, False, 0.03, 0.001, True) -> float32_264<1,192,7,7>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_264<1,192,7,7>) -> float32_265<1,192,7,7>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_264<1,192,7,7>, inplace=False) -> float32_265<1,192,7,7>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_265<1,192,7,7>) -> float32_281<1,192,7,7>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_265<1,192,7,7>) -> float32_273<1,192,7,7>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_265<1,192,7,7>) -> float32_267<1,192,7,7>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_265<1,192,7,7>, float32_266<192,192,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_267<1,192,7,7>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_267<1,192,7,7>) -> float32_272<1,192,7,7>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_267<1,192,7,7>, float32_268<192>, float32_269<192>, float32_270<192>, float32_271<192>, False, 0.03, 0.001) -> float32_272<1,192,7,7>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_267<1,192,7,7>, float32_270<192>, float32_271<192>, float32_268<192>, float32_269<192>, False, 0.03, 0.001, True) -> float32_272<1,192,7,7>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_272<1,192,7,7>) -> float32_273<1,192,7,7>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_272<1,192,7,7>, inplace=False) -> float32_273<1,192,7,7>
#  │   │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_273<1,192,7,7>) -> float32_281<1,192,7,7>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_273<1,192,7,7>) -> float32_275<1,192,7,7>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_273<1,192,7,7>, float32_274<192,192,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_275<1,192,7,7>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_275<1,192,7,7>) -> float32_280<1,192,7,7>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_275<1,192,7,7>, float32_276<192>, float32_277<192>, float32_278<192>, float32_279<192>, False, 0.03, 0.001) -> float32_280<1,192,7,7>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_275<1,192,7,7>, float32_278<192>, float32_279<192>, float32_276<192>, float32_277<192>, False, 0.03, 0.001, True) -> float32_280<1,192,7,7>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_280<1,192,7,7>) -> float32_281<1,192,7,7>
#  │   │   │   │   │   └   └   └· silu[torch.nn.functional](float32_280<1,192,7,7>, inplace=False) -> float32_281<1,192,7,7>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_257<1,384,7,7>) -> float32_289<1,192,7,7>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_257<1,384,7,7>) -> float32_283<1,192,7,7>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_257<1,384,7,7>, float32_282<192,384,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_283<1,192,7,7>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_283<1,192,7,7>) -> float32_288<1,192,7,7>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_283<1,192,7,7>, float32_284<192>, float32_285<192>, float32_286<192>, float32_287<192>, False, 0.03, 0.001) -> float32_288<1,192,7,7>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_283<1,192,7,7>, float32_286<192>, float32_287<192>, float32_284<192>, float32_285<192>, False, 0.03, 0.001, True) -> float32_288<1,192,7,7>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_288<1,192,7,7>) -> float32_289<1,192,7,7>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_288<1,192,7,7>, inplace=False) -> float32_289<1,192,7,7>
#  │   │   │   │   │  cat[torch]((float32_281<1,192,7,7>, float32_289<1,192,7,7>), dim=1) -> float32_290<1,384,7,7>
#  │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_290<1,384,7,7>) -> float32_298<1,384,7,7>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_290<1,384,7,7>) -> float32_292<1,384,7,7>
# ...
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_532<1,96,28,28>) -> float32_540<1,96,28,28>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_532<1,96,28,28>) -> float32_534<1,96,28,28>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_532<1,96,28,28>, float32_533<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_534<1,96,28,28>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_534<1,96,28,28>) -> float32_539<1,96,28,28>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_534<1,96,28,28>, float32_535<96>, float32_536<96>, float32_537<96>, float32_538<96>, False, 0.03, 0.001) -> float32_539<1,96,28,28>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_534<1,96,28,28>, float32_537<96>, float32_538<96>, float32_535<96>, float32_536<96>, False, 0.03, 0.001, True) -> float32_539<1,96,28,28>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_539<1,96,28,28>) -> float32_540<1,96,28,28>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_539<1,96,28,28>, inplace=False) -> float32_540<1,96,28,28>
#  │   │   │  Sequential[torch.nn.modules.container](float32_508<1,96,28,28>) -> float32_556<1,96,28,28>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_508<1,96,28,28>) -> float32_548<1,96,28,28>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_508<1,96,28,28>) -> float32_542<1,96,28,28>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_508<1,96,28,28>, float32_541<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_542<1,96,28,28>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_542<1,96,28,28>) -> float32_547<1,96,28,28>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_542<1,96,28,28>, float32_543<96>, float32_544<96>, float32_545<96>, float32_546<96>, False, 0.03, 0.001) -> float32_547<1,96,28,28>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_542<1,96,28,28>, float32_545<96>, float32_546<96>, float32_543<96>, float32_544<96>, False, 0.03, 0.001, True) -> float32_547<1,96,28,28>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_547<1,96,28,28>) -> float32_548<1,96,28,28>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_547<1,96,28,28>, inplace=False) -> float32_548<1,96,28,28>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_548<1,96,28,28>) -> float32_556<1,96,28,28>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_548<1,96,28,28>) -> float32_550<1,96,28,28>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_548<1,96,28,28>, float32_549<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_550<1,96,28,28>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_550<1,96,28,28>) -> float32_555<1,96,28,28>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_550<1,96,28,28>, float32_551<96>, float32_552<96>, float32_553<96>, float32_554<96>, False, 0.03, 0.001) -> float32_555<1,96,28,28>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_550<1,96,28,28>, float32_553<96>, float32_554<96>, float32_551<96>, float32_552<96>, False, 0.03, 0.001, True) -> float32_555<1,96,28,28>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_555<1,96,28,28>) -> float32_556<1,96,28,28>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_555<1,96,28,28>, inplace=False) -> float32_556<1,96,28,28>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_540<1,96,28,28>) -> float32_559<1,19,28,28>
#  │   │   │   └· conv2d[torch.nn.functional](float32_540<1,96,28,28>, float32_557<19,96,1,1>, float32_558<19>, (1, 1), (0, 0), (1, 1), 1) -> float32_559<1,19,28,28>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_556<1,96,28,28>) -> float32_562<1,4,28,28>
#  │   │   │   └· conv2d[torch.nn.functional](float32_556<1,96,28,28>, float32_560<4,96,1,1>, float32_561<4>, (1, 1), (0, 0), (1, 1), 1) -> float32_562<1,4,28,28>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_556<1,96,28,28>) -> float32_565<1,1,28,28>
#  │   │   │   └· conv2d[torch.nn.functional](float32_556<1,96,28,28>, float32_563<1,96,1,1>, float32_564<1>, (1, 1), (0, 0), (1, 1), 1) -> float32_565<1,1,28,28>
#  │   │   │  Sequential[torch.nn.modules.container](float32_516<1,96,14,14>) -> float32_581<1,96,14,14>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_516<1,96,14,14>) -> float32_573<1,96,14,14>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_516<1,96,14,14>) -> float32_567<1,96,14,14>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_516<1,96,14,14>, float32_566<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_567<1,96,14,14>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_567<1,96,14,14>) -> float32_572<1,96,14,14>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_567<1,96,14,14>, float32_568<96>, float32_569<96>, float32_570<96>, float32_571<96>, False, 0.03, 0.001) -> float32_572<1,96,14,14>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_567<1,96,14,14>, float32_570<96>, float32_571<96>, float32_568<96>, float32_569<96>, False, 0.03, 0.001, True) -> float32_572<1,96,14,14>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_572<1,96,14,14>) -> float32_573<1,96,14,14>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_572<1,96,14,14>, inplace=False) -> float32_573<1,96,14,14>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_573<1,96,14,14>) -> float32_581<1,96,14,14>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_573<1,96,14,14>) -> float32_575<1,96,14,14>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_573<1,96,14,14>, float32_574<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_575<1,96,14,14>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_575<1,96,14,14>) -> float32_580<1,96,14,14>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_575<1,96,14,14>, float32_576<96>, float32_577<96>, float32_578<96>, float32_579<96>, False, 0.03, 0.001) -> float32_580<1,96,14,14>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_575<1,96,14,14>, float32_578<96>, float32_579<96>, float32_576<96>, float32_577<96>, False, 0.03, 0.001, True) -> float32_580<1,96,14,14>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_580<1,96,14,14>) -> float32_581<1,96,14,14>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_580<1,96,14,14>, inplace=False) -> float32_581<1,96,14,14>
#  │   │   │  Sequential[torch.nn.modules.container](float32_516<1,96,14,14>) -> float32_597<1,96,14,14>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_516<1,96,14,14>) -> float32_589<1,96,14,14>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_516<1,96,14,14>) -> float32_583<1,96,14,14>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_516<1,96,14,14>, float32_582<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_583<1,96,14,14>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_583<1,96,14,14>) -> float32_588<1,96,14,14>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_583<1,96,14,14>, float32_584<96>, float32_585<96>, float32_586<96>, float32_587<96>, False, 0.03, 0.001) -> float32_588<1,96,14,14>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_583<1,96,14,14>, float32_586<96>, float32_587<96>, float32_584<96>, float32_585<96>, False, 0.03, 0.001, True) -> float32_588<1,96,14,14>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_588<1,96,14,14>) -> float32_589<1,96,14,14>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_588<1,96,14,14>, inplace=False) -> float32_589<1,96,14,14>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_589<1,96,14,14>) -> float32_597<1,96,14,14>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_589<1,96,14,14>) -> float32_591<1,96,14,14>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_589<1,96,14,14>, float32_590<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_591<1,96,14,14>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_591<1,96,14,14>) -> float32_596<1,96,14,14>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_591<1,96,14,14>, float32_592<96>, float32_593<96>, float32_594<96>, float32_595<96>, False, 0.03, 0.001) -> float32_596<1,96,14,14>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_591<1,96,14,14>, float32_594<96>, float32_595<96>, float32_592<96>, float32_593<96>, False, 0.03, 0.001, True) -> float32_596<1,96,14,14>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_596<1,96,14,14>) -> float32_597<1,96,14,14>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_596<1,96,14,14>, inplace=False) -> float32_597<1,96,14,14>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_581<1,96,14,14>) -> float32_600<1,19,14,14>
#  │   │   │   └· conv2d[torch.nn.functional](float32_581<1,96,14,14>, float32_598<19,96,1,1>, float32_599<19>, (1, 1), (0, 0), (1, 1), 1) -> float32_600<1,19,14,14>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_597<1,96,14,14>) -> float32_603<1,4,14,14>
#  │   │   │   └· conv2d[torch.nn.functional](float32_597<1,96,14,14>, float32_601<4,96,1,1>, float32_602<4>, (1, 1), (0, 0), (1, 1), 1) -> float32_603<1,4,14,14>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_597<1,96,14,14>) -> float32_606<1,1,14,14>
#  │   │   │   └· conv2d[torch.nn.functional](float32_597<1,96,14,14>, float32_604<1,96,1,1>, float32_605<1>, (1, 1), (0, 0), (1, 1), 1) -> float32_606<1,1,14,14>
#  │   │   │  Sequential[torch.nn.modules.container](float32_524<1,96,7,7>) -> float32_622<1,96,7,7>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_524<1,96,7,7>) -> float32_614<1,96,7,7>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_524<1,96,7,7>) -> float32_608<1,96,7,7>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_524<1,96,7,7>, float32_607<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_608<1,96,7,7>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_608<1,96,7,7>) -> float32_613<1,96,7,7>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_608<1,96,7,7>, float32_609<96>, float32_610<96>, float32_611<96>, float32_612<96>, False, 0.03, 0.001) -> float32_613<1,96,7,7>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_608<1,96,7,7>, float32_611<96>, float32_612<96>, float32_609<96>, float32_610<96>, False, 0.03, 0.001, True) -> float32_613<1,96,7,7>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_613<1,96,7,7>) -> float32_614<1,96,7,7>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_613<1,96,7,7>, inplace=False) -> float32_614<1,96,7,7>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_614<1,96,7,7>) -> float32_622<1,96,7,7>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_614<1,96,7,7>) -> float32_616<1,96,7,7>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_614<1,96,7,7>, float32_615<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_616<1,96,7,7>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_616<1,96,7,7>) -> float32_621<1,96,7,7>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_616<1,96,7,7>, float32_617<96>, float32_618<96>, float32_619<96>, float32_620<96>, False, 0.03, 0.001) -> float32_621<1,96,7,7>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_616<1,96,7,7>, float32_619<96>, float32_620<96>, float32_617<96>, float32_618<96>, False, 0.03, 0.001, True) -> float32_621<1,96,7,7>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_621<1,96,7,7>) -> float32_622<1,96,7,7>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_621<1,96,7,7>, inplace=False) -> float32_622<1,96,7,7>
#  │   │   │  Sequential[torch.nn.modules.container](float32_524<1,96,7,7>) -> float32_638<1,96,7,7>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_524<1,96,7,7>) -> float32_630<1,96,7,7>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_524<1,96,7,7>) -> float32_624<1,96,7,7>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_524<1,96,7,7>, float32_623<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_624<1,96,7,7>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_624<1,96,7,7>) -> float32_629<1,96,7,7>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_624<1,96,7,7>, float32_625<96>, float32_626<96>, float32_627<96>, float32_628<96>, False, 0.03, 0.001) -> float32_629<1,96,7,7>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_624<1,96,7,7>, float32_627<96>, float32_628<96>, float32_625<96>, float32_626<96>, False, 0.03, 0.001, True) -> float32_629<1,96,7,7>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_629<1,96,7,7>) -> float32_630<1,96,7,7>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_629<1,96,7,7>, inplace=False) -> float32_630<1,96,7,7>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_630<1,96,7,7>) -> float32_638<1,96,7,7>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_630<1,96,7,7>) -> float32_632<1,96,7,7>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_630<1,96,7,7>, float32_631<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_632<1,96,7,7>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_632<1,96,7,7>) -> float32_637<1,96,7,7>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_632<1,96,7,7>, float32_633<96>, float32_634<96>, float32_635<96>, float32_636<96>, False, 0.03, 0.001) -> float32_637<1,96,7,7>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_632<1,96,7,7>, float32_635<96>, float32_636<96>, float32_633<96>, float32_634<96>, False, 0.03, 0.001, True) -> float32_637<1,96,7,7>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_637<1,96,7,7>) -> float32_638<1,96,7,7>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_637<1,96,7,7>, inplace=False) -> float32_638<1,96,7,7>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_622<1,96,7,7>) -> float32_641<1,19,7,7>
#  │   │   │   └· conv2d[torch.nn.functional](float32_622<1,96,7,7>, float32_639<19,96,1,1>, float32_640<19>, (1, 1), (0, 0), (1, 1), 1) -> float32_641<1,19,7,7>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_638<1,96,7,7>) -> float32_644<1,4,7,7>
#  │   │   │   └· conv2d[torch.nn.functional](float32_638<1,96,7,7>, float32_642<4,96,1,1>, float32_643<4>, (1, 1), (0, 0), (1, 1), 1) -> float32_644<1,4,7,7>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_638<1,96,7,7>) -> float32_647<1,1,7,7>
#  │   └   └   └· conv2d[torch.nn.functional](float32_638<1,96,7,7>, float32_645<1,96,1,1>, float32_646<1>, (1, 1), (0, 0), (1, 1), 1) -> float32_647<1,1,7,7>
#  │  sigmoid[torch](float32_559<1,19,28,28>) -> float32_648<1,19,28,28>
#  │  sigmoid[torch](float32_565<1,1,28,28>) -> float32_649<1,1,28,28>
#  │  cat[torch]((float32_562<1,4,28,28>, float32_649<1,1,28,28>, float32_648<1,19,28,28>), dim=1) -> float32_650<1,24,28,28>
#  │  flatten[torch](float32_650<1,24,28,28>, start_dim=2) -> float32_651<1,24,784>
#  │  sigmoid[torch](float32_600<1,19,14,14>) -> float32_652<1,19,14,14>
#  │  sigmoid[torch](float32_606<1,1,14,14>) -> float32_653<1,1,14,14>
#  │  cat[torch]((float32_603<1,4,14,14>, float32_653<1,1,14,14>, float32_652<1,19,14,14>), dim=1) -> float32_654<1,24,14,14>
#  │  flatten[torch](float32_654<1,24,14,14>, start_dim=2) -> float32_655<1,24,196>
#  │  sigmoid[torch](float32_641<1,19,7,7>) -> float32_656<1,19,7,7>
#  │  sigmoid[torch](float32_647<1,1,7,7>) -> float32_657<1,1,7,7>
#  │  cat[torch]((float32_644<1,4,7,7>, float32_657<1,1,7,7>, float32_656<1,19,7,7>), dim=1) -> float32_658<1,24,7,7>
#  │  flatten[torch](float32_658<1,24,7,7>, start_dim=2) -> float32_659<1,24,49>
#  │  cat[torch]([float32_651<1,24,784>, float32_655<1,24,196>, float32_659<1,24,49>], dim=2) -> float32_660<1,24,1029>
#  └· permute[torch.Tensor](float32_660<1,24,1029>, 0, 2, 1) -> float32_661<1,1029,24>
#
# [Nobuco] Conversion complete. Elapsed time: 3.71 sec.

# %% [markdown]
# ### Save the Keras Model in SavedModel format

# %%
# Set the folder path for the SavedModel files
savedmodel_dir = Path(f"{checkpoint_dir}/{colormap_path.stem.removesuffix('-colormap')}-{model_type}-tf")
# Save the TensorFlow model to disk
keras_model.save(savedmodel_dir, save_format="tf")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: pytorch-yolox-object-detector/2024-09-21_20-57-52/hagrid-sample-30k-384p-yolox_tiny-tf/assets
# INFO:tensorflow:Assets written to: pytorch-yolox-object-detector/2024-09-21_20-57-52/hagrid-sample-30k-384p-yolox_tiny-tf/assets

# %% [markdown]
# ## Exporting the Model to TensorFlow.js

# %%
# Set the path for TensorFlow.js model files
tfjs_model_dir = f"{savedmodel_dir}js-uint8"

# Convert the TensorFlow SavedModel to a TensorFlow.js Graph model
converters.convert_tf_saved_model(saved_model_dir=str(savedmodel_dir), 
                                  output_dir=tfjs_model_dir, 
                                  quantization_dtype_map={quantization.QUANTIZATION_DTYPE_UINT8:True}
                                 )
# Out:
# 2024-09-26 11:55:41.798924: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-26 11:55:41.802201: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-09-26 11:55:41.802305: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-09-26 11:55:41.802476: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-26 11:55:41.806181: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
