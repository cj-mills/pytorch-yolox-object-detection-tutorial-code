# %% [markdown]
# ## Setting Up Your Python Environment

# %%
# %%capture
# # Install PyTorch with CUDA
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# # Install additional dependencies
# !pip install pandas nobuco tensorflowjs

# # Install utility packages
# !pip install cjm_yolox_pytorch

# %% [markdown]
# ## Importing the Required Dependencies

# %%
# Import Python Standard Library dependencies
import json
from pathlib import Path

# Import YOLOX package
from cjm_yolox_pytorch.model import build_model
from cjm_yolox_pytorch.inference import YOLOXInferenceWrapper

# Import the pandas package
import pandas as pd

# Import PyTorch dependencies
import torch

# Import Nobuco dependencies
from nobuco import pytorch_to_keras, ChannelOrder

# Import TensorFlow
import tensorflow as tf

# Import TensorFlow.js dependencies
from tensorflowjs import converters, quantization
# Out:
# 2023-09-26 12:01:33.891573: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-26 12:01:33.919443: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-26 12:01:34.568231: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Setting Up the Project

# %% [markdown]
# ### Set the Directory Paths

# %%
# The name for the project
project_name = f"pytorch-yolox-object-detector"

# The path for the project folder
project_dir = Path(f"./{project_name}/")

# Create the project directory if it does not already exist
project_dir.mkdir(parents=True, exist_ok=True)

# The path to the checkpoint folder
checkpoint_dir = Path(project_dir/f"2023-08-17_16-14-43")

pd.Series({
    "Project Directory:": project_dir,
    "Checkpoint Directory:": checkpoint_dir,
}).to_frame().style.hide(axis='columns')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ed5e5">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed5e5_level0_row0" class="row_heading level0 row0" >Project Directory:</th>
#       <td id="T_ed5e5_row0_col0" class="data row0 col0" >pytorch-yolox-object-detector</td>
#     </tr>
#     <tr>
#       <th id="T_ed5e5_level0_row1" class="row_heading level0 row1" >Checkpoint Directory:</th>
#       <td id="T_ed5e5_row1_col0" class="data row1 col0" >pytorch-yolox-object-detector/2023-08-17_16-14-43</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Loading the Checkpoint Data

# %% [markdown]
# ### Load the Colormap

# %%
# The colormap path
colormap_path = list(checkpoint_dir.glob('*colormap.json'))[0]

# Load the JSON colormap data
with open(colormap_path, 'r') as file:
        colormap_json = json.load(file)

# Convert the JSON data to a dictionary        
colormap_dict = {item['label']: item['color'] for item in colormap_json['items']}

# Extract the class names from the colormap
class_names = list(colormap_dict.keys())

# Make a copy of the colormap in integer format
int_colors = [tuple(int(c*255) for c in color) for color in colormap_dict.values()]

# %% [markdown]
# ### Load the Normalization Statistics

# %%
# The normalization stats path
norm_stats_path = checkpoint_dir/'norm_stats.json'

# Read the normalization stats from the JSON file
with open(norm_stats_path, "r") as f:
    norm_stats_dict = json.load(f)

# Convert the dictionary to a tuple
norm_stats = (norm_stats_dict["mean"], norm_stats_dict["std_dev"])

# Print the mean and standard deviation
pd.DataFrame(norm_stats)
# Out:
#      0    1    2
# 0  0.5  0.5  0.5
# 1  1.0  1.0  1.0

# %% [markdown]
# ### Load the Model Checkpoint

# %%
# The model checkpoint path
checkpoint_path = list(checkpoint_dir.glob('*.pth'))[0]

# Load the model checkpoint onto the CPU
model_checkpoint = torch.load(checkpoint_path, map_location='cpu')

# %% [markdown]
# ### Load the Trained YOLOX Model

# %%
# Select the YOLOX model configuration
model_type = checkpoint_path.stem

# Create a YOLOX model with the number of output classes equal to the number of class names
model = build_model(model_type, len(class_names))

# Initialize the model with the checkpoint parameters and buffers
model.load_state_dict(model_checkpoint)
# Out:
# The file ./pretrained_checkpoints/yolox_tiny.pth already exists and overwrite is set to False.
# <All keys matched successfully>

# %% [markdown]
# ## Converting the Model to TensorFlow

# %% [markdown]
# ### Prepare the Model for Inference

# %%
# Convert the normalization stats to tensors
mean_tensor = torch.tensor(norm_stats[0]).view(1, 3, 1, 1)
std_tensor = torch.tensor(norm_stats[1]).view(1, 3, 1, 1)

# Set the model to evaluation mode
model.eval();

# Wrap the model with preprocessing and post-processing steps
wrapped_model = YOLOXInferenceWrapper(model, 
                                      mean_tensor, 
                                      std_tensor, 
                                      scale_inp=True, # Scale input values from the rang [0,255] to [0,1]
                                      channels_last=True, # Have the model expect input in channels-last format
                                      run_box_and_prob_calculation=False # Enable or disable post-processing steps
                                     )

# %% [markdown]
# ### Prepare the Input Tensor

# %%
input_tensor = torch.randn(1, 256, 256, 3)

# %% [markdown]
# ### Convert the PyTorch Model to Keras

# %%
keras_model = pytorch_to_keras(
    wrapped_model, 
    args=[input_tensor],
    inputs_channel_order=ChannelOrder.PYTORCH,
    outputs_channel_order=ChannelOrder.PYTORCH, 
)
# Out:
# 2023-09-26 12:01:36.089900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-26 12:01:36.090163: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<built-in method max_pool2d of type object at 0x7f6293c028a0>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck->MaxPool2d->max_pool2d] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.275232
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<function boolean_dispatch.<locals>.fn at 0x7f6225fa31a0>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck->MaxPool2d] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.275232
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'torch.nn.modules.pooling.MaxPool2d'>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.275232
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<built-in method max_pool2d of type object at 0x7f6293c028a0>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck->MaxPool2d->max_pool2d] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.244484
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<function boolean_dispatch.<locals>.fn at 0x7f6225fa31a0>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck->MaxPool2d] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.244484
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'torch.nn.modules.pooling.MaxPool2d'>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.244484
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<built-in method max_pool2d of type object at 0x7f6293c028a0>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck->MaxPool2d->max_pool2d] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.212370
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<function boolean_dispatch.<locals>.fn at 0x7f6225fa31a0>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck->MaxPool2d] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.212370
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'torch.nn.modules.pooling.MaxPool2d'>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential->SPPBottleneck] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.212370
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.SPPBottleneck'>|YOLOXInferenceWrapper->YOLOX->CSPDarknet->Sequential] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.144613
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'torch.nn.modules.container.Sequential'>|YOLOXInferenceWrapper->YOLOX->CSPDarknet] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.076689
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.CSPDarknet'>|YOLOXInferenceWrapper->YOLOX] conversion procedure might be incorrect: max. discrepancy for output #2 is 0.076688
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.117783
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #1 is 0.071098
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #2 is 0.050317
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #3 is 0.029130
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #4 is 0.029129
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #5 is 0.013246
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #6 is 0.096523
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #7 is 0.102599
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.model.YOLOX'>|YOLOXInferenceWrapper] conversion procedure might be incorrect: max. discrepancy for output #8 is 0.047482
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/converters/validation.py:51: RuntimeWarning: [<class 'cjm_yolox_pytorch.inference.YOLOXInferenceWrapper'>|] conversion procedure might be incorrect: max. discrepancy for output #0 is 0.029130
#   warnings.warn(
# Legend:
#     Green — conversion successful
#     Yellow — conversion imprecise
#     Red — conversion failed
#     Red — no converter found
#     Bold — conversion applied directly
#     * — subgraph reused
#     Tensor — this output is not dependent on any of subgraph's input tensors
#     Tensor — this input is a parameter / constant
#     Tensor — this tensor is useless
#
#  (!) Max diff 0.029130
#  I  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/nobuco/trace/trace.py", line 236
#  D  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/cjm_yolox_pytorch/inference.py", line 24
# YOLOXInferenceWrapper[cjm_yolox_pytorch.inference](float32_0<1,256,256,3>) -> float32_662<1,1344,24>
#  │  __truediv__[torch.Tensor](float32_0<1,256,256,3>, 255.0) -> float32_1<1,256,256,3>
#  │  permute[torch.Tensor](float32_1<1,256,256,3>, 0, 3, 1, 2) -> float32_2<1,3,256,256>
#  │  __sub__[torch.Tensor](float32_2<1,3,256,256>, float32_3<1,3,1,1>) -> float32_4<1,3,256,256>
#  │  __truediv__[torch.Tensor](float32_4<1,3,256,256>, float32_5<1,3,1,1>) -> float32_6<1,3,256,256>
#  │   (!) Max diff 0.117783
#  │   I  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/cjm_yolox_pytorch/inference.py", line 145
#  │   D  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/cjm_yolox_pytorch/model.py", line 694
#  │  YOLOX[cjm_yolox_pytorch.model](float32_6<1,3,256,256>) -> ([float32_560<1,19,32,32>, float32_601<1,19,16,16>, float32_642<1,19,8,8>], [float32_563<1,4,32,32>, float32_604<1,4,16,16>, float32_645<1,4,8,8>], [float32_566<1,1,32,32>, float32_607<1,1,16,16>, float32_648<1,1,8,8>])
#  │   │   (!) Max diff 0.076688
#  │   │   I  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/cjm_yolox_pytorch/model.py", line 721
#  │   │   D  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/cjm_yolox_pytorch/model.py", line 349
#  │   │  CSPDarknet[cjm_yolox_pytorch.model](float32_6<1,3,256,256>) -> (float32_149<1,96,32,32>, float32_230<1,192,16,16>, float32_299<1,384,8,8>)
#  │   │   │  Focus[cjm_yolox_pytorch.model](float32_6<1,3,256,256>) -> float32_19<1,24,128,128>
#  │   │   │   │  __getitem__[torch.Tensor](float32_6<1,3,256,256>, (..., ::2, ::2)) -> float32_7<1,3,128,128>
#  │   │   │   │  __getitem__[torch.Tensor](float32_6<1,3,256,256>, (..., ::2, 1::2)) -> float32_8<1,3,128,128>
#  │   │   │   │  __getitem__[torch.Tensor](float32_6<1,3,256,256>, (..., 1::2, ::2)) -> float32_9<1,3,128,128>
#  │   │   │   │  __getitem__[torch.Tensor](float32_6<1,3,256,256>, (..., 1::2, 1::2)) -> float32_10<1,3,128,128>
#  │   │   │   │  cat[torch]((float32_7<1,3,128,128>, float32_8<1,3,128,128>, float32_9<1,3,128,128>, float32_10<1,3,128,128>), dim=1) -> float32_11<1,12,128,128>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_11<1,12,128,128>) -> float32_19<1,24,128,128>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_11<1,12,128,128>) -> float32_13<1,24,128,128>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_11<1,12,128,128>, float32_12<24,12,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_13<1,24,128,128>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_13<1,24,128,128>) -> float32_18<1,24,128,128>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_13<1,24,128,128>, float32_14<24>, float32_15<24>, float32_16<24>, float32_17<24>, False, 0.03, 0.001) -> float32_18<1,24,128,128>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_13<1,24,128,128>, float32_16<24>, float32_17<24>, float32_14<24>, float32_15<24>, False, 0.03, 0.001, True) -> float32_18<1,24,128,128>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_18<1,24,128,128>) -> float32_19<1,24,128,128>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_18<1,24,128,128>, inplace=False) -> float32_19<1,24,128,128>
#  │   │   │  Sequential[torch.nn.modules.container](float32_19<1,24,128,128>) -> float32_68<1,48,64,64>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_19<1,24,128,128>) -> float32_27<1,48,64,64>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_19<1,24,128,128>) -> float32_21<1,48,64,64>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_19<1,24,128,128>, float32_20<48,24,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_21<1,48,64,64>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_21<1,48,64,64>) -> float32_26<1,48,64,64>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_21<1,48,64,64>, float32_22<48>, float32_23<48>, float32_24<48>, float32_25<48>, False, 0.03, 0.001) -> float32_26<1,48,64,64>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_21<1,48,64,64>, float32_24<48>, float32_25<48>, float32_22<48>, float32_23<48>, False, 0.03, 0.001, True) -> float32_26<1,48,64,64>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_26<1,48,64,64>) -> float32_27<1,48,64,64>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_26<1,48,64,64>, inplace=False) -> float32_27<1,48,64,64>
#  │   │   │   ├· CSPLayer[cjm_yolox_pytorch.model](float32_27<1,48,64,64>) -> float32_68<1,48,64,64>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_27<1,48,64,64>) -> float32_35<1,24,64,64>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_27<1,48,64,64>) -> float32_29<1,24,64,64>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_27<1,48,64,64>, float32_28<24,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_29<1,24,64,64>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_29<1,24,64,64>) -> float32_34<1,24,64,64>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_29<1,24,64,64>, float32_30<24>, float32_31<24>, float32_32<24>, float32_33<24>, False, 0.03, 0.001) -> float32_34<1,24,64,64>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_29<1,24,64,64>, float32_32<24>, float32_33<24>, float32_30<24>, float32_31<24>, False, 0.03, 0.001, True) -> float32_34<1,24,64,64>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_34<1,24,64,64>) -> float32_35<1,24,64,64>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_34<1,24,64,64>, inplace=False) -> float32_35<1,24,64,64>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_35<1,24,64,64>) -> float32_51<1,24,64,64>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_35<1,24,64,64>) -> float32_43<1,24,64,64>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_35<1,24,64,64>) -> float32_37<1,24,64,64>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_35<1,24,64,64>, float32_36<24,24,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_37<1,24,64,64>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_37<1,24,64,64>) -> float32_42<1,24,64,64>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_37<1,24,64,64>, float32_38<24>, float32_39<24>, float32_40<24>, float32_41<24>, False, 0.03, 0.001) -> float32_42<1,24,64,64>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_37<1,24,64,64>, float32_40<24>, float32_41<24>, float32_38<24>, float32_39<24>, False, 0.03, 0.001, True) -> float32_42<1,24,64,64>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_42<1,24,64,64>) -> float32_43<1,24,64,64>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_42<1,24,64,64>, inplace=False) -> float32_43<1,24,64,64>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_43<1,24,64,64>) -> float32_51<1,24,64,64>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_43<1,24,64,64>) -> float32_45<1,24,64,64>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_43<1,24,64,64>, float32_44<24,24,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_45<1,24,64,64>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_45<1,24,64,64>) -> float32_50<1,24,64,64>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_45<1,24,64,64>, float32_46<24>, float32_47<24>, float32_48<24>, float32_49<24>, False, 0.03, 0.001) -> float32_50<1,24,64,64>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_45<1,24,64,64>, float32_48<24>, float32_49<24>, float32_46<24>, float32_47<24>, False, 0.03, 0.001, True) -> float32_50<1,24,64,64>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_50<1,24,64,64>) -> float32_51<1,24,64,64>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_50<1,24,64,64>, inplace=False) -> float32_51<1,24,64,64>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_35<1,24,64,64>) -> float32_35<1,24,64,64>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   └· __iadd__[torch.Tensor](float32_51<1,24,64,64>, float32_35<1,24,64,64>) -> float32_51<1,24,64,64>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_27<1,48,64,64>) -> float32_59<1,24,64,64>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_27<1,48,64,64>) -> float32_53<1,24,64,64>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_27<1,48,64,64>, float32_52<24,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_53<1,24,64,64>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_53<1,24,64,64>) -> float32_58<1,24,64,64>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_53<1,24,64,64>, float32_54<24>, float32_55<24>, float32_56<24>, float32_57<24>, False, 0.03, 0.001) -> float32_58<1,24,64,64>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_53<1,24,64,64>, float32_56<24>, float32_57<24>, float32_54<24>, float32_55<24>, False, 0.03, 0.001, True) -> float32_58<1,24,64,64>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_58<1,24,64,64>) -> float32_59<1,24,64,64>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_58<1,24,64,64>, inplace=False) -> float32_59<1,24,64,64>
#  │   │   │   │   │  cat[torch]((float32_51<1,24,64,64>, float32_59<1,24,64,64>), dim=1) -> float32_60<1,48,64,64>
#  │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_60<1,48,64,64>) -> float32_68<1,48,64,64>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_60<1,48,64,64>) -> float32_62<1,48,64,64>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_60<1,48,64,64>, float32_61<48,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_62<1,48,64,64>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_62<1,48,64,64>) -> float32_67<1,48,64,64>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_62<1,48,64,64>, float32_63<48>, float32_64<48>, float32_65<48>, float32_66<48>, False, 0.03, 0.001) -> float32_67<1,48,64,64>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_62<1,48,64,64>, float32_65<48>, float32_66<48>, float32_63<48>, float32_64<48>, False, 0.03, 0.001, True) -> float32_67<1,48,64,64>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_67<1,48,64,64>) -> float32_68<1,48,64,64>
#  │   │   │   └   └   └   └· silu[torch.nn.functional](float32_67<1,48,64,64>, inplace=False) -> float32_68<1,48,64,64>
#  │   │   ├· Sequential[torch.nn.modules.container](float32_68<1,48,64,64>) -> float32_149<1,96,32,32>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_68<1,48,64,64>) -> float32_76<1,96,32,32>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_68<1,48,64,64>) -> float32_70<1,96,32,32>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_68<1,48,64,64>, float32_69<96,48,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_70<1,96,32,32>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_70<1,96,32,32>) -> float32_75<1,96,32,32>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_70<1,96,32,32>, float32_71<96>, float32_72<96>, float32_73<96>, float32_74<96>, False, 0.03, 0.001) -> float32_75<1,96,32,32>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_70<1,96,32,32>, float32_73<96>, float32_74<96>, float32_71<96>, float32_72<96>, False, 0.03, 0.001, True) -> float32_75<1,96,32,32>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_75<1,96,32,32>) -> float32_76<1,96,32,32>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_75<1,96,32,32>, inplace=False) -> float32_76<1,96,32,32>
#  │   │   │   ├· CSPLayer[cjm_yolox_pytorch.model](float32_76<1,96,32,32>) -> float32_149<1,96,32,32>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_76<1,96,32,32>) -> float32_84<1,48,32,32>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_76<1,96,32,32>) -> float32_78<1,48,32,32>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_76<1,96,32,32>, float32_77<48,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_78<1,48,32,32>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_78<1,48,32,32>) -> float32_83<1,48,32,32>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_78<1,48,32,32>, float32_79<48>, float32_80<48>, float32_81<48>, float32_82<48>, False, 0.03, 0.001) -> float32_83<1,48,32,32>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_78<1,48,32,32>, float32_81<48>, float32_82<48>, float32_79<48>, float32_80<48>, False, 0.03, 0.001, True) -> float32_83<1,48,32,32>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_83<1,48,32,32>) -> float32_84<1,48,32,32>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_83<1,48,32,32>, inplace=False) -> float32_84<1,48,32,32>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_84<1,48,32,32>) -> float32_100<1,48,32,32>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_84<1,48,32,32>) -> float32_92<1,48,32,32>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_84<1,48,32,32>) -> float32_86<1,48,32,32>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_84<1,48,32,32>, float32_85<48,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_86<1,48,32,32>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_86<1,48,32,32>) -> float32_91<1,48,32,32>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_86<1,48,32,32>, float32_87<48>, float32_88<48>, float32_89<48>, float32_90<48>, False, 0.03, 0.001) -> float32_91<1,48,32,32>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_86<1,48,32,32>, float32_89<48>, float32_90<48>, float32_87<48>, float32_88<48>, False, 0.03, 0.001, True) -> float32_91<1,48,32,32>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_91<1,48,32,32>) -> float32_92<1,48,32,32>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_91<1,48,32,32>, inplace=False) -> float32_92<1,48,32,32>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_92<1,48,32,32>) -> float32_100<1,48,32,32>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_92<1,48,32,32>) -> float32_94<1,48,32,32>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_92<1,48,32,32>, float32_93<48,48,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_94<1,48,32,32>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_94<1,48,32,32>) -> float32_99<1,48,32,32>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_94<1,48,32,32>, float32_95<48>, float32_96<48>, float32_97<48>, float32_98<48>, False, 0.03, 0.001) -> float32_99<1,48,32,32>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_94<1,48,32,32>, float32_97<48>, float32_98<48>, float32_95<48>, float32_96<48>, False, 0.03, 0.001, True) -> float32_99<1,48,32,32>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_99<1,48,32,32>) -> float32_100<1,48,32,32>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_99<1,48,32,32>, inplace=False) -> float32_100<1,48,32,32>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_84<1,48,32,32>) -> float32_84<1,48,32,32>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   └· __iadd__[torch.Tensor](float32_100<1,48,32,32>, float32_84<1,48,32,32>) -> float32_100<1,48,32,32>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_100<1,48,32,32>) -> float32_116<1,48,32,32>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_100<1,48,32,32>) -> float32_108<1,48,32,32>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_100<1,48,32,32>) -> float32_102<1,48,32,32>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_100<1,48,32,32>, float32_101<48,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_102<1,48,32,32>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_102<1,48,32,32>) -> float32_107<1,48,32,32>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_102<1,48,32,32>, float32_103<48>, float32_104<48>, float32_105<48>, float32_106<48>, False, 0.03, 0.001) -> float32_107<1,48,32,32>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_102<1,48,32,32>, float32_105<48>, float32_106<48>, float32_103<48>, float32_104<48>, False, 0.03, 0.001, True) -> float32_107<1,48,32,32>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_107<1,48,32,32>) -> float32_108<1,48,32,32>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_107<1,48,32,32>, inplace=False) -> float32_108<1,48,32,32>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_108<1,48,32,32>) -> float32_116<1,48,32,32>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_108<1,48,32,32>) -> float32_110<1,48,32,32>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_108<1,48,32,32>, float32_109<48,48,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_110<1,48,32,32>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_110<1,48,32,32>) -> float32_115<1,48,32,32>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_110<1,48,32,32>, float32_111<48>, float32_112<48>, float32_113<48>, float32_114<48>, False, 0.03, 0.001) -> float32_115<1,48,32,32>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_110<1,48,32,32>, float32_113<48>, float32_114<48>, float32_111<48>, float32_112<48>, False, 0.03, 0.001, True) -> float32_115<1,48,32,32>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_115<1,48,32,32>) -> float32_116<1,48,32,32>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_115<1,48,32,32>, inplace=False) -> float32_116<1,48,32,32>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_100<1,48,32,32>) -> float32_100<1,48,32,32>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   └· __iadd__[torch.Tensor](float32_116<1,48,32,32>, float32_100<1,48,32,32>) -> float32_116<1,48,32,32>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_116<1,48,32,32>) -> float32_132<1,48,32,32>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_116<1,48,32,32>) -> float32_124<1,48,32,32>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_116<1,48,32,32>) -> float32_118<1,48,32,32>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_116<1,48,32,32>, float32_117<48,48,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_118<1,48,32,32>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_118<1,48,32,32>) -> float32_123<1,48,32,32>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_118<1,48,32,32>, float32_119<48>, float32_120<48>, float32_121<48>, float32_122<48>, False, 0.03, 0.001) -> float32_123<1,48,32,32>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_118<1,48,32,32>, float32_121<48>, float32_122<48>, float32_119<48>, float32_120<48>, False, 0.03, 0.001, True) -> float32_123<1,48,32,32>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_123<1,48,32,32>) -> float32_124<1,48,32,32>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_123<1,48,32,32>, inplace=False) -> float32_124<1,48,32,32>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_124<1,48,32,32>) -> float32_132<1,48,32,32>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_124<1,48,32,32>) -> float32_126<1,48,32,32>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_124<1,48,32,32>, float32_125<48,48,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_126<1,48,32,32>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_126<1,48,32,32>) -> float32_131<1,48,32,32>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_126<1,48,32,32>, float32_127<48>, float32_128<48>, float32_129<48>, float32_130<48>, False, 0.03, 0.001) -> float32_131<1,48,32,32>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_126<1,48,32,32>, float32_129<48>, float32_130<48>, float32_127<48>, float32_128<48>, False, 0.03, 0.001, True) -> float32_131<1,48,32,32>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_131<1,48,32,32>) -> float32_132<1,48,32,32>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_131<1,48,32,32>, inplace=False) -> float32_132<1,48,32,32>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_116<1,48,32,32>) -> float32_116<1,48,32,32>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   └· __iadd__[torch.Tensor](float32_132<1,48,32,32>, float32_116<1,48,32,32>) -> float32_132<1,48,32,32>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_76<1,96,32,32>) -> float32_140<1,48,32,32>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_76<1,96,32,32>) -> float32_134<1,48,32,32>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_76<1,96,32,32>, float32_133<48,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_134<1,48,32,32>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_134<1,48,32,32>) -> float32_139<1,48,32,32>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_134<1,48,32,32>, float32_135<48>, float32_136<48>, float32_137<48>, float32_138<48>, False, 0.03, 0.001) -> float32_139<1,48,32,32>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_134<1,48,32,32>, float32_137<48>, float32_138<48>, float32_135<48>, float32_136<48>, False, 0.03, 0.001, True) -> float32_139<1,48,32,32>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_139<1,48,32,32>) -> float32_140<1,48,32,32>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_139<1,48,32,32>, inplace=False) -> float32_140<1,48,32,32>
#  │   │   │   │   │  cat[torch]((float32_132<1,48,32,32>, float32_140<1,48,32,32>), dim=1) -> float32_141<1,96,32,32>
#  │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_141<1,96,32,32>) -> float32_149<1,96,32,32>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_141<1,96,32,32>) -> float32_143<1,96,32,32>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_141<1,96,32,32>, float32_142<96,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_143<1,96,32,32>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_143<1,96,32,32>) -> float32_148<1,96,32,32>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_143<1,96,32,32>, float32_144<96>, float32_145<96>, float32_146<96>, float32_147<96>, False, 0.03, 0.001) -> float32_148<1,96,32,32>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_143<1,96,32,32>, float32_146<96>, float32_147<96>, float32_144<96>, float32_145<96>, False, 0.03, 0.001, True) -> float32_148<1,96,32,32>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_148<1,96,32,32>) -> float32_149<1,96,32,32>
#  │   │   │   └   └   └   └· silu[torch.nn.functional](float32_148<1,96,32,32>, inplace=False) -> float32_149<1,96,32,32>
#  │   │   ├· Sequential[torch.nn.modules.container](float32_149<1,96,32,32>) -> float32_230<1,192,16,16>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_149<1,96,32,32>) -> float32_157<1,192,16,16>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_149<1,96,32,32>) -> float32_151<1,192,16,16>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_149<1,96,32,32>, float32_150<192,96,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_151<1,192,16,16>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_151<1,192,16,16>) -> float32_156<1,192,16,16>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_151<1,192,16,16>, float32_152<192>, float32_153<192>, float32_154<192>, float32_155<192>, False, 0.03, 0.001) -> float32_156<1,192,16,16>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_151<1,192,16,16>, float32_154<192>, float32_155<192>, float32_152<192>, float32_153<192>, False, 0.03, 0.001, True) -> float32_156<1,192,16,16>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_156<1,192,16,16>) -> float32_157<1,192,16,16>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_156<1,192,16,16>, inplace=False) -> float32_157<1,192,16,16>
#  │   │   │   ├· CSPLayer[cjm_yolox_pytorch.model](float32_157<1,192,16,16>) -> float32_230<1,192,16,16>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_157<1,192,16,16>) -> float32_165<1,96,16,16>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_157<1,192,16,16>) -> float32_159<1,96,16,16>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_157<1,192,16,16>, float32_158<96,192,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_159<1,96,16,16>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_159<1,96,16,16>) -> float32_164<1,96,16,16>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_159<1,96,16,16>, float32_160<96>, float32_161<96>, float32_162<96>, float32_163<96>, False, 0.03, 0.001) -> float32_164<1,96,16,16>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_159<1,96,16,16>, float32_162<96>, float32_163<96>, float32_160<96>, float32_161<96>, False, 0.03, 0.001, True) -> float32_164<1,96,16,16>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_164<1,96,16,16>) -> float32_165<1,96,16,16>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_164<1,96,16,16>, inplace=False) -> float32_165<1,96,16,16>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_165<1,96,16,16>) -> float32_181<1,96,16,16>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_165<1,96,16,16>) -> float32_173<1,96,16,16>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_165<1,96,16,16>) -> float32_167<1,96,16,16>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_165<1,96,16,16>, float32_166<96,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_167<1,96,16,16>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_167<1,96,16,16>) -> float32_172<1,96,16,16>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_167<1,96,16,16>, float32_168<96>, float32_169<96>, float32_170<96>, float32_171<96>, False, 0.03, 0.001) -> float32_172<1,96,16,16>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_167<1,96,16,16>, float32_170<96>, float32_171<96>, float32_168<96>, float32_169<96>, False, 0.03, 0.001, True) -> float32_172<1,96,16,16>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_172<1,96,16,16>) -> float32_173<1,96,16,16>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_172<1,96,16,16>, inplace=False) -> float32_173<1,96,16,16>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_173<1,96,16,16>) -> float32_181<1,96,16,16>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_173<1,96,16,16>) -> float32_175<1,96,16,16>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_173<1,96,16,16>, float32_174<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_175<1,96,16,16>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_175<1,96,16,16>) -> float32_180<1,96,16,16>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_175<1,96,16,16>, float32_176<96>, float32_177<96>, float32_178<96>, float32_179<96>, False, 0.03, 0.001) -> float32_180<1,96,16,16>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_175<1,96,16,16>, float32_178<96>, float32_179<96>, float32_176<96>, float32_177<96>, False, 0.03, 0.001, True) -> float32_180<1,96,16,16>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_180<1,96,16,16>) -> float32_181<1,96,16,16>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_180<1,96,16,16>, inplace=False) -> float32_181<1,96,16,16>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_165<1,96,16,16>) -> float32_165<1,96,16,16>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   └· __iadd__[torch.Tensor](float32_181<1,96,16,16>, float32_165<1,96,16,16>) -> float32_181<1,96,16,16>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_181<1,96,16,16>) -> float32_197<1,96,16,16>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_181<1,96,16,16>) -> float32_189<1,96,16,16>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_181<1,96,16,16>) -> float32_183<1,96,16,16>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_181<1,96,16,16>, float32_182<96,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_183<1,96,16,16>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_183<1,96,16,16>) -> float32_188<1,96,16,16>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_183<1,96,16,16>, float32_184<96>, float32_185<96>, float32_186<96>, float32_187<96>, False, 0.03, 0.001) -> float32_188<1,96,16,16>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_183<1,96,16,16>, float32_186<96>, float32_187<96>, float32_184<96>, float32_185<96>, False, 0.03, 0.001, True) -> float32_188<1,96,16,16>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_188<1,96,16,16>) -> float32_189<1,96,16,16>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_188<1,96,16,16>, inplace=False) -> float32_189<1,96,16,16>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_189<1,96,16,16>) -> float32_197<1,96,16,16>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_189<1,96,16,16>) -> float32_191<1,96,16,16>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_189<1,96,16,16>, float32_190<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_191<1,96,16,16>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_191<1,96,16,16>) -> float32_196<1,96,16,16>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_191<1,96,16,16>, float32_192<96>, float32_193<96>, float32_194<96>, float32_195<96>, False, 0.03, 0.001) -> float32_196<1,96,16,16>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_191<1,96,16,16>, float32_194<96>, float32_195<96>, float32_192<96>, float32_193<96>, False, 0.03, 0.001, True) -> float32_196<1,96,16,16>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_196<1,96,16,16>) -> float32_197<1,96,16,16>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_196<1,96,16,16>, inplace=False) -> float32_197<1,96,16,16>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_181<1,96,16,16>) -> float32_181<1,96,16,16>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   └· __iadd__[torch.Tensor](float32_197<1,96,16,16>, float32_181<1,96,16,16>) -> float32_197<1,96,16,16>
#  │   │   │   │   │  DarknetBottleneck[cjm_yolox_pytorch.model](float32_197<1,96,16,16>) -> float32_213<1,96,16,16>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_197<1,96,16,16>) -> float32_205<1,96,16,16>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_197<1,96,16,16>) -> float32_199<1,96,16,16>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_197<1,96,16,16>, float32_198<96,96,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_199<1,96,16,16>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_199<1,96,16,16>) -> float32_204<1,96,16,16>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_199<1,96,16,16>, float32_200<96>, float32_201<96>, float32_202<96>, float32_203<96>, False, 0.03, 0.001) -> float32_204<1,96,16,16>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_199<1,96,16,16>, float32_202<96>, float32_203<96>, float32_200<96>, float32_201<96>, False, 0.03, 0.001, True) -> float32_204<1,96,16,16>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_204<1,96,16,16>) -> float32_205<1,96,16,16>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_204<1,96,16,16>, inplace=False) -> float32_205<1,96,16,16>
#  │   │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_205<1,96,16,16>) -> float32_213<1,96,16,16>
#  │   │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_205<1,96,16,16>) -> float32_207<1,96,16,16>
#  │   │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_205<1,96,16,16>, float32_206<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_207<1,96,16,16>
#  │   │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_207<1,96,16,16>) -> float32_212<1,96,16,16>
#  │   │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_207<1,96,16,16>, float32_208<96>, float32_209<96>, float32_210<96>, float32_211<96>, False, 0.03, 0.001) -> float32_212<1,96,16,16>
#  │   │   │   │   │   │   │   └   └· batch_norm[torch](float32_207<1,96,16,16>, float32_210<96>, float32_211<96>, float32_208<96>, float32_209<96>, False, 0.03, 0.001, True) -> float32_212<1,96,16,16>
#  │   │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_212<1,96,16,16>) -> float32_213<1,96,16,16>
#  │   │   │   │   │   │   └   └· silu[torch.nn.functional](float32_212<1,96,16,16>, inplace=False) -> float32_213<1,96,16,16>
#  │   │   │   │   │   │  Identity[torch.nn.modules.linear](float32_197<1,96,16,16>) -> float32_197<1,96,16,16>
#  │   │   │   │   │   │   (!) Inplace
#  │   │   │   │   │   └· __iadd__[torch.Tensor](float32_213<1,96,16,16>, float32_197<1,96,16,16>) -> float32_213<1,96,16,16>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_157<1,192,16,16>) -> float32_221<1,96,16,16>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_157<1,192,16,16>) -> float32_215<1,96,16,16>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_157<1,192,16,16>, float32_214<96,192,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_215<1,96,16,16>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_215<1,96,16,16>) -> float32_220<1,96,16,16>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_215<1,96,16,16>, float32_216<96>, float32_217<96>, float32_218<96>, float32_219<96>, False, 0.03, 0.001) -> float32_220<1,96,16,16>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_215<1,96,16,16>, float32_218<96>, float32_219<96>, float32_216<96>, float32_217<96>, False, 0.03, 0.001, True) -> float32_220<1,96,16,16>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_220<1,96,16,16>) -> float32_221<1,96,16,16>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_220<1,96,16,16>, inplace=False) -> float32_221<1,96,16,16>
#  │   │   │   │   │  cat[torch]((float32_213<1,96,16,16>, float32_221<1,96,16,16>), dim=1) -> float32_222<1,192,16,16>
#  │   │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_222<1,192,16,16>) -> float32_230<1,192,16,16>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_222<1,192,16,16>) -> float32_224<1,192,16,16>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_222<1,192,16,16>, float32_223<192,192,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_224<1,192,16,16>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_224<1,192,16,16>) -> float32_229<1,192,16,16>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_224<1,192,16,16>, float32_225<192>, float32_226<192>, float32_227<192>, float32_228<192>, False, 0.03, 0.001) -> float32_229<1,192,16,16>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_224<1,192,16,16>, float32_227<192>, float32_228<192>, float32_225<192>, float32_226<192>, False, 0.03, 0.001, True) -> float32_229<1,192,16,16>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_229<1,192,16,16>) -> float32_230<1,192,16,16>
#  │   │   │   └   └   └   └· silu[torch.nn.functional](float32_229<1,192,16,16>, inplace=False) -> float32_230<1,192,16,16>
#  │   │   │   (!) Max diff 0.076689
#  │   │   │   I  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/cjm_yolox_pytorch/model.py", line 445
#  │   │   │   D  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/container.py", line 42
#  │   │   ├· Sequential[torch.nn.modules.container](float32_230<1,192,16,16>) -> float32_299<1,384,8,8>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_230<1,192,16,16>) -> float32_238<1,384,8,8>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_230<1,192,16,16>) -> float32_232<1,384,8,8>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_230<1,192,16,16>, float32_231<384,192,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_232<1,384,8,8>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_232<1,384,8,8>) -> float32_237<1,384,8,8>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_232<1,384,8,8>, float32_233<384>, float32_234<384>, float32_235<384>, float32_236<384>, False, 0.03, 0.001) -> float32_237<1,384,8,8>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_232<1,384,8,8>, float32_235<384>, float32_236<384>, float32_233<384>, float32_234<384>, False, 0.03, 0.001, True) -> float32_237<1,384,8,8>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_237<1,384,8,8>) -> float32_238<1,384,8,8>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_237<1,384,8,8>, inplace=False) -> float32_238<1,384,8,8>
#  │   │   │   │   (!) Max diff 0.144613
#  │   │   │   │   I  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/container.py", line 217
#  │   │   │   │   D  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/cjm_yolox_pytorch/model.py", line 304
#  │   │   │   │  SPPBottleneck[cjm_yolox_pytorch.model](float32_238<1,384,8,8>) -> float32_258<1,384,8,8>
#  │   │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_238<1,384,8,8>) -> float32_246<1,192,8,8>
#  │   │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_238<1,384,8,8>) -> float32_240<1,192,8,8>
#  │   │   │   │   │   │   └· conv2d[torch.nn.functional](float32_238<1,384,8,8>, float32_239<192,384,1,1>, None, (1, 1), (0, 0), (1, 1), 1) -> float32_240<1,192,8,8>
#  │   │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_240<1,192,8,8>) -> float32_245<1,192,8,8>
#  │   │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_240<1,192,8,8>, float32_241<192>, float32_242<192>, float32_243<192>, float32_244<192>, False, 0.03, 0.001) -> float32_245<1,192,8,8>
#  │   │   │   │   │   │   └   └· batch_norm[torch](float32_240<1,192,8,8>, float32_243<192>, float32_244<192>, float32_241<192>, float32_242<192>, False, 0.03, 0.001, True) -> float32_245<1,192,8,8>
#  │   │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_245<1,192,8,8>) -> float32_246<1,192,8,8>
#  │   │   │   │   │   └   └· silu[torch.nn.functional](float32_245<1,192,8,8>, inplace=False) -> float32_246<1,192,8,8>
#  │   │   │   │   │   (!) Max diff 0.275232
#  │   │   │   │   │   I  File "/home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/cjm_yolox_pytorch/model.py", line 342
# ...
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_533<1,96,32,32>) -> float32_541<1,96,32,32>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_533<1,96,32,32>) -> float32_535<1,96,32,32>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_533<1,96,32,32>, float32_534<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_535<1,96,32,32>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_535<1,96,32,32>) -> float32_540<1,96,32,32>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_535<1,96,32,32>, float32_536<96>, float32_537<96>, float32_538<96>, float32_539<96>, False, 0.03, 0.001) -> float32_540<1,96,32,32>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_535<1,96,32,32>, float32_538<96>, float32_539<96>, float32_536<96>, float32_537<96>, False, 0.03, 0.001, True) -> float32_540<1,96,32,32>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_540<1,96,32,32>) -> float32_541<1,96,32,32>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_540<1,96,32,32>, inplace=False) -> float32_541<1,96,32,32>
#  │   │   │  Sequential[torch.nn.modules.container](float32_509<1,96,32,32>) -> float32_557<1,96,32,32>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_509<1,96,32,32>) -> float32_549<1,96,32,32>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_509<1,96,32,32>) -> float32_543<1,96,32,32>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_509<1,96,32,32>, float32_542<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_543<1,96,32,32>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_543<1,96,32,32>) -> float32_548<1,96,32,32>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_543<1,96,32,32>, float32_544<96>, float32_545<96>, float32_546<96>, float32_547<96>, False, 0.03, 0.001) -> float32_548<1,96,32,32>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_543<1,96,32,32>, float32_546<96>, float32_547<96>, float32_544<96>, float32_545<96>, False, 0.03, 0.001, True) -> float32_548<1,96,32,32>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_548<1,96,32,32>) -> float32_549<1,96,32,32>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_548<1,96,32,32>, inplace=False) -> float32_549<1,96,32,32>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_549<1,96,32,32>) -> float32_557<1,96,32,32>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_549<1,96,32,32>) -> float32_551<1,96,32,32>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_549<1,96,32,32>, float32_550<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_551<1,96,32,32>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_551<1,96,32,32>) -> float32_556<1,96,32,32>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_551<1,96,32,32>, float32_552<96>, float32_553<96>, float32_554<96>, float32_555<96>, False, 0.03, 0.001) -> float32_556<1,96,32,32>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_551<1,96,32,32>, float32_554<96>, float32_555<96>, float32_552<96>, float32_553<96>, False, 0.03, 0.001, True) -> float32_556<1,96,32,32>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_556<1,96,32,32>) -> float32_557<1,96,32,32>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_556<1,96,32,32>, inplace=False) -> float32_557<1,96,32,32>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_541<1,96,32,32>) -> float32_560<1,19,32,32>
#  │   │   │   └· conv2d[torch.nn.functional](float32_541<1,96,32,32>, float32_558<19,96,1,1>, float32_559<19>, (1, 1), (0, 0), (1, 1), 1) -> float32_560<1,19,32,32>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_557<1,96,32,32>) -> float32_563<1,4,32,32>
#  │   │   │   └· conv2d[torch.nn.functional](float32_557<1,96,32,32>, float32_561<4,96,1,1>, float32_562<4>, (1, 1), (0, 0), (1, 1), 1) -> float32_563<1,4,32,32>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_557<1,96,32,32>) -> float32_566<1,1,32,32>
#  │   │   │   └· conv2d[torch.nn.functional](float32_557<1,96,32,32>, float32_564<1,96,1,1>, float32_565<1>, (1, 1), (0, 0), (1, 1), 1) -> float32_566<1,1,32,32>
#  │   │   │  Sequential[torch.nn.modules.container](float32_517<1,96,16,16>) -> float32_582<1,96,16,16>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_517<1,96,16,16>) -> float32_574<1,96,16,16>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_517<1,96,16,16>) -> float32_568<1,96,16,16>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_517<1,96,16,16>, float32_567<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_568<1,96,16,16>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_568<1,96,16,16>) -> float32_573<1,96,16,16>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_568<1,96,16,16>, float32_569<96>, float32_570<96>, float32_571<96>, float32_572<96>, False, 0.03, 0.001) -> float32_573<1,96,16,16>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_568<1,96,16,16>, float32_571<96>, float32_572<96>, float32_569<96>, float32_570<96>, False, 0.03, 0.001, True) -> float32_573<1,96,16,16>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_573<1,96,16,16>) -> float32_574<1,96,16,16>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_573<1,96,16,16>, inplace=False) -> float32_574<1,96,16,16>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_574<1,96,16,16>) -> float32_582<1,96,16,16>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_574<1,96,16,16>) -> float32_576<1,96,16,16>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_574<1,96,16,16>, float32_575<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_576<1,96,16,16>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_576<1,96,16,16>) -> float32_581<1,96,16,16>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_576<1,96,16,16>, float32_577<96>, float32_578<96>, float32_579<96>, float32_580<96>, False, 0.03, 0.001) -> float32_581<1,96,16,16>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_576<1,96,16,16>, float32_579<96>, float32_580<96>, float32_577<96>, float32_578<96>, False, 0.03, 0.001, True) -> float32_581<1,96,16,16>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_581<1,96,16,16>) -> float32_582<1,96,16,16>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_581<1,96,16,16>, inplace=False) -> float32_582<1,96,16,16>
#  │   │   │  Sequential[torch.nn.modules.container](float32_517<1,96,16,16>) -> float32_598<1,96,16,16>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_517<1,96,16,16>) -> float32_590<1,96,16,16>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_517<1,96,16,16>) -> float32_584<1,96,16,16>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_517<1,96,16,16>, float32_583<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_584<1,96,16,16>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_584<1,96,16,16>) -> float32_589<1,96,16,16>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_584<1,96,16,16>, float32_585<96>, float32_586<96>, float32_587<96>, float32_588<96>, False, 0.03, 0.001) -> float32_589<1,96,16,16>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_584<1,96,16,16>, float32_587<96>, float32_588<96>, float32_585<96>, float32_586<96>, False, 0.03, 0.001, True) -> float32_589<1,96,16,16>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_589<1,96,16,16>) -> float32_590<1,96,16,16>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_589<1,96,16,16>, inplace=False) -> float32_590<1,96,16,16>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_590<1,96,16,16>) -> float32_598<1,96,16,16>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_590<1,96,16,16>) -> float32_592<1,96,16,16>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_590<1,96,16,16>, float32_591<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_592<1,96,16,16>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_592<1,96,16,16>) -> float32_597<1,96,16,16>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_592<1,96,16,16>, float32_593<96>, float32_594<96>, float32_595<96>, float32_596<96>, False, 0.03, 0.001) -> float32_597<1,96,16,16>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_592<1,96,16,16>, float32_595<96>, float32_596<96>, float32_593<96>, float32_594<96>, False, 0.03, 0.001, True) -> float32_597<1,96,16,16>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_597<1,96,16,16>) -> float32_598<1,96,16,16>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_597<1,96,16,16>, inplace=False) -> float32_598<1,96,16,16>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_582<1,96,16,16>) -> float32_601<1,19,16,16>
#  │   │   │   └· conv2d[torch.nn.functional](float32_582<1,96,16,16>, float32_599<19,96,1,1>, float32_600<19>, (1, 1), (0, 0), (1, 1), 1) -> float32_601<1,19,16,16>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_598<1,96,16,16>) -> float32_604<1,4,16,16>
#  │   │   │   └· conv2d[torch.nn.functional](float32_598<1,96,16,16>, float32_602<4,96,1,1>, float32_603<4>, (1, 1), (0, 0), (1, 1), 1) -> float32_604<1,4,16,16>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_598<1,96,16,16>) -> float32_607<1,1,16,16>
#  │   │   │   └· conv2d[torch.nn.functional](float32_598<1,96,16,16>, float32_605<1,96,1,1>, float32_606<1>, (1, 1), (0, 0), (1, 1), 1) -> float32_607<1,1,16,16>
#  │   │   │  Sequential[torch.nn.modules.container](float32_525<1,96,8,8>) -> float32_623<1,96,8,8>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_525<1,96,8,8>) -> float32_615<1,96,8,8>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_525<1,96,8,8>) -> float32_609<1,96,8,8>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_525<1,96,8,8>, float32_608<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_609<1,96,8,8>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_609<1,96,8,8>) -> float32_614<1,96,8,8>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_609<1,96,8,8>, float32_610<96>, float32_611<96>, float32_612<96>, float32_613<96>, False, 0.03, 0.001) -> float32_614<1,96,8,8>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_609<1,96,8,8>, float32_612<96>, float32_613<96>, float32_610<96>, float32_611<96>, False, 0.03, 0.001, True) -> float32_614<1,96,8,8>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_614<1,96,8,8>) -> float32_615<1,96,8,8>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_614<1,96,8,8>, inplace=False) -> float32_615<1,96,8,8>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_615<1,96,8,8>) -> float32_623<1,96,8,8>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_615<1,96,8,8>) -> float32_617<1,96,8,8>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_615<1,96,8,8>, float32_616<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_617<1,96,8,8>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_617<1,96,8,8>) -> float32_622<1,96,8,8>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_617<1,96,8,8>, float32_618<96>, float32_619<96>, float32_620<96>, float32_621<96>, False, 0.03, 0.001) -> float32_622<1,96,8,8>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_617<1,96,8,8>, float32_620<96>, float32_621<96>, float32_618<96>, float32_619<96>, False, 0.03, 0.001, True) -> float32_622<1,96,8,8>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_622<1,96,8,8>) -> float32_623<1,96,8,8>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_622<1,96,8,8>, inplace=False) -> float32_623<1,96,8,8>
#  │   │   │  Sequential[torch.nn.modules.container](float32_525<1,96,8,8>) -> float32_639<1,96,8,8>
#  │   │   │   │  ConvModule[cjm_yolox_pytorch.model](float32_525<1,96,8,8>) -> float32_631<1,96,8,8>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_525<1,96,8,8>) -> float32_625<1,96,8,8>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_525<1,96,8,8>, float32_624<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_625<1,96,8,8>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_625<1,96,8,8>) -> float32_630<1,96,8,8>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_625<1,96,8,8>, float32_626<96>, float32_627<96>, float32_628<96>, float32_629<96>, False, 0.03, 0.001) -> float32_630<1,96,8,8>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_625<1,96,8,8>, float32_628<96>, float32_629<96>, float32_626<96>, float32_627<96>, False, 0.03, 0.001, True) -> float32_630<1,96,8,8>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_630<1,96,8,8>) -> float32_631<1,96,8,8>
#  │   │   │   │   └   └· silu[torch.nn.functional](float32_630<1,96,8,8>, inplace=False) -> float32_631<1,96,8,8>
#  │   │   │   ├· ConvModule[cjm_yolox_pytorch.model](float32_631<1,96,8,8>) -> float32_639<1,96,8,8>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_631<1,96,8,8>) -> float32_633<1,96,8,8>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_631<1,96,8,8>, float32_632<96,96,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_633<1,96,8,8>
#  │   │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_633<1,96,8,8>) -> float32_638<1,96,8,8>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_633<1,96,8,8>, float32_634<96>, float32_635<96>, float32_636<96>, float32_637<96>, False, 0.03, 0.001) -> float32_638<1,96,8,8>
#  │   │   │   │   │   └   └· batch_norm[torch](float32_633<1,96,8,8>, float32_636<96>, float32_637<96>, float32_634<96>, float32_635<96>, False, 0.03, 0.001, True) -> float32_638<1,96,8,8>
#  │   │   │   │   ├· SiLU[torch.nn.modules.activation](float32_638<1,96,8,8>) -> float32_639<1,96,8,8>
#  │   │   │   └   └   └· silu[torch.nn.functional](float32_638<1,96,8,8>, inplace=False) -> float32_639<1,96,8,8>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_623<1,96,8,8>) -> float32_642<1,19,8,8>
#  │   │   │   └· conv2d[torch.nn.functional](float32_623<1,96,8,8>, float32_640<19,96,1,1>, float32_641<19>, (1, 1), (0, 0), (1, 1), 1) -> float32_642<1,19,8,8>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_639<1,96,8,8>) -> float32_645<1,4,8,8>
#  │   │   │   └· conv2d[torch.nn.functional](float32_639<1,96,8,8>, float32_643<4,96,1,1>, float32_644<4>, (1, 1), (0, 0), (1, 1), 1) -> float32_645<1,4,8,8>
#  │   │   ├· Conv2d[torch.nn.modules.conv](float32_639<1,96,8,8>) -> float32_648<1,1,8,8>
#  │   └   └   └· conv2d[torch.nn.functional](float32_639<1,96,8,8>, float32_646<1,96,1,1>, float32_647<1>, (1, 1), (0, 0), (1, 1), 1) -> float32_648<1,1,8,8>
#  │  sigmoid[torch](float32_560<1,19,32,32>) -> float32_649<1,19,32,32>
#  │  sigmoid[torch](float32_566<1,1,32,32>) -> float32_650<1,1,32,32>
#  │  cat[torch]((float32_563<1,4,32,32>, float32_650<1,1,32,32>, float32_649<1,19,32,32>), dim=1) -> float32_651<1,24,32,32>
#  │  flatten[torch](float32_651<1,24,32,32>, start_dim=2) -> float32_652<1,24,1024>
#  │  sigmoid[torch](float32_601<1,19,16,16>) -> float32_653<1,19,16,16>
#  │  sigmoid[torch](float32_607<1,1,16,16>) -> float32_654<1,1,16,16>
#  │  cat[torch]((float32_604<1,4,16,16>, float32_654<1,1,16,16>, float32_653<1,19,16,16>), dim=1) -> float32_655<1,24,16,16>
#  │  flatten[torch](float32_655<1,24,16,16>, start_dim=2) -> float32_656<1,24,256>
#  │  sigmoid[torch](float32_642<1,19,8,8>) -> float32_657<1,19,8,8>
#  │  sigmoid[torch](float32_648<1,1,8,8>) -> float32_658<1,1,8,8>
#  │  cat[torch]((float32_645<1,4,8,8>, float32_658<1,1,8,8>, float32_657<1,19,8,8>), dim=1) -> float32_659<1,24,8,8>
#  │  flatten[torch](float32_659<1,24,8,8>, start_dim=2) -> float32_660<1,24,64>
#  │  cat[torch]([float32_652<1,24,1024>, float32_656<1,24,256>, float32_660<1,24,64>], dim=2) -> float32_661<1,24,1344>
#  └· permute[torch.Tensor](float32_661<1,24,1344>, 0, 2, 1) -> float32_662<1,1344,24>
#
# Conversion complete. Elapsed time: 3.31 sec.

# %% [markdown]
# ## Enabling Dynamic Input Dimensions

# %% [markdown]
# ### Define New Input Dimensions

# %%
# Get the current input shape
input_shape = keras_model.layers[0].input_shape[0][1:]

# Make every dimension except the channel dimension dynamic
dynamic_input_shape = tuple(i if i == 3 else None for i in input_shape)

pd.Series({
    "Source Input Shape:": input_shape,
    "Dynamic Input Shape:": dynamic_input_shape,
}).to_frame().style.hide(axis='columns')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3698a">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3698a_level0_row0" class="row_heading level0 row0" >Source Input Shape:</th>
#       <td id="T_3698a_row0_col0" class="data row0 col0" >(256, 256, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_3698a_level0_row1" class="row_heading level0 row1" >Dynamic Input Shape:</th>
#       <td id="T_3698a_row1_col0" class="data row1 col0" >(None, None, 3)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Build Dynamic Keras Model

# %%
# Create a Keras tensor with the dynamic input shape
inputs = tf.keras.Input(shape=dynamic_input_shape)
# Get a Keras tensor with the dynamic output shape 
outputs = keras_model(inputs)

# Build a Keras model with dynamic input and output shapes
dynamic_model = tf.keras.Model(inputs, outputs)
# Add the trained weights to the dynamic Keras model
dynamic_model.set_weights(keras_model.get_weights())
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.compat.v1.transpose), but are not present in its tracked objects:   <tf.Variable 'weight:0' shape=(1, 3, 1, 1) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.compat.v1.transpose_1), but are not present in its tracked objects:   <tf.Variable 'weight:0' shape=(1, 3, 1, 1) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.

# %% [markdown]
# ### Save the Keras Model in SavedModel format

# %%
# Set the folder path for the SavedModel files
savedmodel_dir = Path(f"{checkpoint_dir}/{colormap_path.stem.removesuffix('-colormap')}-{model_type}-tf")
# Save the TensorFlow model to disk
dynamic_model.save(savedmodel_dir, save_format="tf")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: pytorch-yolox-object-detector/2023-08-17_16-14-43/hagrid-sample-30k-384p-yolox_tiny-tf/assets
# INFO:tensorflow:Assets written to: pytorch-yolox-object-detector/2023-08-17_16-14-43/hagrid-sample-30k-384p-yolox_tiny-tf/assets

# %% [markdown]
# ## Exporting the Model to TensorFlow.js

# %%
# Set the path for TensorFlow.js model files
tfjs_model_dir = f"{savedmodel_dir}js-uint8"

# Convert the TensorFlow SavedModel to a TensorFlow.js Graph model
converters.convert_tf_saved_model(saved_model_dir=str(savedmodel_dir), 
                                  output_dir=tfjs_model_dir, 
                                  quantization_dtype_map={quantization.QUANTIZATION_DTYPE_UINT8:True}
                                 )
# Out:
# 2023-09-26 12:02:48.644820: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-26 12:02:48.644926: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2023-09-26 12:02:48.645059: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2023-09-26 12:02:48.645252: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-26 12:02:48.645310: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
